# %% [markdown]
# This notebook does the following:
#     - Generates a table of tags with the number of times they've been searched
#     - A demo of recommending tags based on Tag Search History

# %%
import pandas as pd
import numpy as np

# %%
# Connect to the database
import pymysql.cursors
import json

userId = []
loginId = []
tagSearch = []
tstamp = []
# Connect to the database
connection = pymysql.connect(host="127.0.0.1",
                             user="web",
                             password="atth1132",
                             db="ML3_mirror")

try:
    with connection.cursor() as cursor:
        # This query select rows from log_trailer_actions where the action is either TrailerModalLaunched or Recommendations Refreshed
        # These two actions indicate that a recommendation list is generated. 
        
        sql = """SELECT * FROM log_action
        WHERE action = "pageview" and logJson LIKE ("%base.explore%") and logJson LIKE ("%tag%")
        """
        
        cursor.execute(sql)

        for row in cursor:
            logjson = json.loads(row[4])
            params = logjson["params"]
            
            if ('tag' in params):
                tagList = params['tag'].split(',')
                for tag in tagList:
                    userId.append(row[1])
                    loginId.append(row[2])
                    tagSearch.append(tag)
                    tstamp.append(row[5])
                    
finally: 
    connection.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b97e71c1f8e6> in <module>()
#      22         """
#      23
# ---> 24         cursor.execute(sql)
#      25
#      26         for row in cursor:
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     163         query = self.mogrify(query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#     167         return result
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     319         conn = self._get_db()
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     858                 sql = sql.encode(self.encoding, 'surrogateescape')
#     859         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 860         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     861         return self._affected_rows
#     862
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1059         else:
#    1060             result = MySQLResult(self)
# -> 1061             result.read()
#    1062         self._result = result
#    1063         if result.server_status is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1354                 self._read_load_local_packet(first_packet)
#    1355             else:
# -> 1356                 self._read_result_packet(first_packet)
#    1357         finally:
#    1358             self.connection = None
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _read_result_packet(self, first_packet)
#    1420         self.field_count = first_packet.read_length_encoded_integer()
#    1421         self._get_descriptions()
# -> 1422         self._read_rowdata_packet()
#    1423
#    1424     def _read_rowdata_packet_unbuffered(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _read_rowdata_packet(self)
#    1454         rows = []
#    1455         while True:
# -> 1456             packet = self.connection._read_packet()
#    1457             if self._check_packet_is_eof(packet):
#    1458                 self.connection = None  # release reference to kill cyclic reference.
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1006             self._next_seq_id = (self._next_seq_id + 1) % 256
#    1007
# -> 1008             recv_data = self._read_bytes(bytes_to_read)
#    1009             if DEBUG: dump_packet(recv_data)
#    1010             buff += recv_data
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#    1023         while True:
#    1024             try:
# -> 1025                 data = self._rfile.read(num_bytes)
#    1026                 break
#    1027             except (IOError, OSError) as e:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
tag_search2 = pd.DataFrame({"userId":userId, "loginId":loginId,"tagSearch":tagSearch,"tstamp":tstamp})

# %% [markdown]
# #### Save the dataframe to csv file

# %% [markdown]
# #### this file saves a list of tags searched in one entry

# %%
tag_search.to_csv("Datasets/tag_search_history.csv")

# %% [markdown]
# #### this file split a list of tags searched into multiple entries

# %%
tag_search2.to_csv("Datasets/tag_search_history_2.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-98758f07827f> in <module>()
# ----> 1 tag_search2.to_csv("../tag_search_history_2.csv")
#
# NameError: name 'tag_search2' is not defined

# %%
tag_search2.groupby(["userId","tagSearch"]).count().sort_values(by="loginId").reset_index()
# Out:
#        userId                    tagSearch  loginId  tstamp
# 0      254463                     dramatic        1       1
# 1      255479                  bittersweet        1       1
# 2      262827             good versus evil        1       1
# 3      262827                    mythology        1       1
# 4      262827              special effects        1       1
# 5      262827                     touching        1       1
# 6      262829                           ai        1       1
# 7      262829      artificial intelligence        1       1
# 8      262829                        blood        1       1
# 9      262829                  chick flick        1       1
# 10     262829                   dark humor        1       1
# 11     262829                     dramatic        1       1
# 12     262829                    feel-good        1       1
# 13     262829                  good acting        1       1
# 14     262829                      intense        1       1
# 15     262829            social commentary        1       1
# 16     262829                     touching        1       1
# 17     262838  central intelligence agency        1       1
# 18     262838                colin farrell        1       1
# 19     262838                      hacking        1       1
# 20     262838                          spy        1       1
# 21     262838               spy on the run        1       1
# 22     255479             great soundtrack        1       1
# 23     262839                  jane austen        1       1
# 24     255479              no happy ending        1       1
# 25     262827                    feel-good        1       1
# 26     262803                    mythology        1       1
# 27     262803              special effects        1       1
# 28     262805                    Dystopian        1       1
# 29     262810                       action        1       1
# ...       ...                          ...      ...     ...
# 82684  268337                  good acting      135     135
# 82685  268337                     dramatic      135     135
# 82686  268337                   dark humor      135     135
# 82687  268337                      classic      135     135
# 82688  260293              talking animals      152     152
# 82689  264050             good versus evil      153     153
# 82690  264050                    mythology      153     153
# 82691  264050                       action      153     153
# 82692  264050                   dark humor      153     153
# 82693  264050           computer animation      153     153
# 82694  264050                        blood      153     153
# 82695  264050            social commentary      153     153
# 82696  264050                    fun movie      153     153
# 82697  264050              special effects      153     153
# 82698  260293                 period piece      173     173
# 82699  267018                       action      187     187
# 82700  267018           computer animation      187     187
# 82701  267018                    fun movie      187     187
# 82702  267018             good versus evil      187     187
# 82703  267018                    mythology      187     187
# 82704  267018              special effects      187     187
# 82705  255969                      classic      549     549
# 82706  255969              special effects      549     549
# 82707  255969                       action      549     549
# 82708  255969                  masterpiece      549     549
# 82709  255969                     quotable      549     549
# 82710  255969                    fun movie      549     549
# 82711  255969                     touching      549     549
# 82712  255969                  chick flick      549     549
# 82713  255969                    feel-good      549     549
#
# [82714 rows x 4 columns]

# %% [markdown]
# ### Recommending tags based on Tag Search History
#
# #### A demo of recommending tags based on Tag Search History for user 134088

# %%
tag_search = pd.read_csv("Datasets/tag_search_history_2.csv")
tag_search.rename(columns={"tagSearch":"tag"},inplace=True)

# %%
# Load tag search history for user 134088

tag_search_134088 = tag_search[tag_search.userId == 134088]

# %%
tag_search_134088 = tag_search[tag_search.userId == 134088]
tag_search_134088_agg = tag_search_134088.groupby(["userId","tag"]).count().reset_index()
tag_search_134088_agg.drop(["loginId","tstamp"],axis=1,inplace=True)
tag_search_134088_agg.rename(columns={"Unnamed: 0":"num_tag_search"},inplace=True)

# %% [markdown]
# #### Merge Tag-search table with Tag-Score table

# %%
# This block counts how many times a tag has been applied; 
# Used for weighting user tags

import pymysql.cursors
import json

# Connect to the database
connection = pymysql.connect(host="127.0.0.1",
                             user="web",
                             password="atth1132",
                             db="ML3_mirror")
try:
    with connection.cursor() as cursor:
            sql = "SELECT * FROM tag_movie"
            cursor.execute(sql)
            result = cursor.fetchall()
            
finally: 
    connection.close()

# %%
movie_tag_app = pd.DataFrame(list(result), columns=['movieId','tag','numApps','numPositive','numNeutral','numNegative','numDownvotes','score'])
movie_tag_app
# Out:
#         movieId                                                tag  numApps  \
# 0             1                   2009 reissue in Stereoscopic 3-D        1
# 1             1                                                 3D        3
# 2             1  55 movies every kid should see--Entertainment ...        1
# 3             1                                             action        1
# 4             1                                      action figure        1
# 5             1                                     action figures        1
# 6             1                                          adventure       17
# 7             1                                    almost favorite        1
# 8             1                                 American Animation        1
# 9             1                                           animated       17
# 10            1                                          animation       77
# 11            1                                         animmation        1
# 12            1                                                avi        1
# 13            1                                           BD-Video        1
# 14            1                  Best of Rotten Tomatoes: All Time        1
# 15            1                                           birthday        1
# 16            1                                                boy        1
# 17            1                                      boy next door        1
# 18            1                                             bright        1
# 19            1                                        buddy movie        9
# 20            1                                           bullying        1
# 21            1                                                buy        1
# 22            1                                     Buzz Lightyear        1
# 23            1                                            Cartoon        8
# 24            1                                       CG animation        1
# 25            1                                                cgi        8
# 26            1                                        CGI classic        1
# 27            1                                           childish        1
# 28            1                                           children       31
# 29            1                                   children cartoon        1
# ...         ...                                                ...      ...
# 458992   189587                                         capitalism        1
# 458993   189587                                 chemical companies        1
# 458994   189587                                          chemicals        1
# 458995   189587                                       corporations        1
# 458996   189587                                        documentary        1
# 458997   189587                                             health        1
# 458998   189587                                           relevant        1
# 458999   189587                                             toxics        1
# 459000   189595                                        bureaucracy        1
# 459001   189595                                        exaggerated        1
# 459002   189595                                               math        1
# 459003   189595                                        mathematics        1
# 459004   189595                                            parents        1
# 459005   189595                                         relativism        1
# 459006   189595                                             school        1
# 459007   189595                                            teacher        1
# 459008   189595                                   twist at the end        1
# 459009   189641                                               love        1
# 459010   189647                                        anti-christ        1
# 459011   189647                                         archbishop        1
# 459012   189647                                             killer        1
# 459013   189647                                           murderer        1
# 459014   189647                                             racist        1
# 459015   189649                                     violent father        1
# 459016   189659                                     drug addiction        1
# 459017   189663                                         small town        1
# 459018   189669                                        modernistic        1
# 459019   189669                                  needed sub-titles        1
# 459020   189669                                           powerful        1
# 459021   189671                                             disney        1
#
#         numPositive  numNeutral  numNegative  numDownvotes  score
# 0                 1           0            0             2   -1.0
# 1                 0           3            0             3    0.0
# 2                 0           1            0             2   -1.0
# 3                 0           1            0             1    0.0
# 4                 0           1            0             2   -1.0
# 5                 0           1            0             1    0.0
# 6                14           3            0             4   13.0
# 7                 0           1            0             5   -4.0
# 8                 0           1            0             1    0.0
# 9                 9           5            3             5   12.0
# 10               37          33            7            10   67.0
# 11                0           1            0             0    1.0
# 12                0           1            0             3   -2.0
# 13                1           0            0             2   -1.0
# 14                0           1            0             0    1.0
# 15                0           1            0             1    0.0
# 16                0           1            0             0    1.0
# 17                0           1            0             0    1.0
# 18                0           1            0             3   -2.0
# 19                4           3            2             2    7.0
# 20                0           1            0             0    1.0
# 21                0           1            0             7   -6.0
# 22                0           1            0             2   -1.0
# 23                0           7            1             2    6.0
# 24                0           1            0             2   -1.0
# 25                2           6            0             3    5.0
# 26                0           1            0             1    0.0
# 27                0           0            1             0    1.0
# 28                5          10           16             4   27.0
# 29                0           1            0             1    0.0
# ...             ...         ...          ...           ...    ...
# 458992            1           0            0             0    1.0
# 458993            0           1            0             0    1.0
# 458994            0           1            0             0    1.0
# 458995            1           0            0             0    1.0
# 458996            1           0            0             0    1.0
# 458997            1           0            0             0    1.0
# 458998            1           0            0             0    1.0
# 458999            0           1            0             0    1.0
# 459000            0           1            0             0    1.0
# 459001            0           0            1             0    1.0
# 459002            0           1            0             0    1.0
# 459003            0           1            0             0    1.0
# 459004            0           1            0             0    1.0
# 459005            0           1            0             0    1.0
# 459006            0           1            0             0    1.0
# 459007            0           1            0             0    1.0
# 459008            0           1            0             0    1.0
# 459009            0           0            1             0    1.0
# 459010            0           1            0             0    1.0
# 459011            0           1            0             0    1.0
# 459012            0           1            0             0    1.0
# 459013            0           1            0             0    1.0
# 459014            0           1            0             0    1.0
# 459015            0           1            0             0    1.0
# 459016            0           1            0             0    1.0
# 459017            0           1            0             0    1.0
# 459018            1           0            0             0    1.0
# 459019            0           1            0             0    1.0
# 459020            1           0            0             0    1.0
# 459021            0           1            0             0    1.0
#
# [459022 rows x 8 columns]

# %% [markdown]
# #### Sum the scores of movie-tag across all movies

# %%
movie_tag_score_sum = movie_tag_app.groupby(["tag"]).sum().reset_index().sort_values(by="score",ascending=False)
movie_tag_score_sum.head(10)
# Out:
#                       tag    movieId  numApps  numPositive  numNeutral  \
# 61428              sci-fi   29177589     8998         6811        2064
# 29521         atmospheric   22176986     6034         5524         483
# 65957             surreal   29702438     5047         4256         669
# 27521              action   62353012     5917         3687        1996
# 68716        twist ending   14480865     4614         4031         476
# 70135  visually appealing   20031591     4102         3854         232
# 39157            dystopia   26252247     4124         3195         824
# 35356              comedy  103626267     5557         3654        1813
# 71389      woman director  404272929     3621            5        3616
# 37108         dark comedy   31890149     3847         3267         532
#
#        numNegative  numDownvotes   score
# 61428          123          1284  7714.0
# 29521           27           763  5271.0
# 65957          122           554  4493.0
# 27521          234          1515  4402.0
# 68716          107           589  4025.0
# 70135           16           307  3795.0
# 39157          105           367  3757.0
# 35356           90          1902  3655.0
# 71389            0             0  3621.0
# 37108           48           421  3426.0

# %% [markdown]
# #### Match User's Tag-Search-History with Tag Score Sums

# %%
user_134088_tag_activity = pd.merge(tag_search_134088_agg, movie_tag_score_sum, on=['tag'], how='left')
user_134088_tag_activity.dropna(inplace=True)

# %%
user_134088_tag_activity_agg = user_134088_tag_activity.groupby(["tag"]).sum().reset_index().sort_values(by="score",ascending=False)

# Choose 10 as score threshold
# Exclude tags with a score < 10
user_134088_tag_activity_agg = user_134088_tag_activity_agg.loc[user_134088_tag_activity_agg["score"]>=10]
user_134088_tag_activity_agg.head(10)
# Out:
#                   tag  userId  num_tag_search     movieId  numApps  \
# 46            surreal  134088               1  29702438.0   5047.0
# 1              action  134088               1  62353012.0   5917.0
# 36         psychology  134088               1  12818669.0   3556.0
# 42              space  134088               1  20550858.0   3044.0
# 41  social commentary  134088               2  23265238.0   2934.0
# 45          superhero  134088               1  25827465.0   2797.0
# 6        black comedy  134088               1  10241959.0   2103.0
# 25           mindfuck  134088               9   5545415.0   1639.0
# 34           politics  134088               1  48412050.0   1749.0
# 40                sex  134088               1  75720383.0   1182.0
#
#     numPositive  numNeutral  numNegative  numDownvotes   score
# 46       4256.0       669.0        122.0         554.0  4493.0
# 1        3687.0      1996.0        234.0        1515.0  4402.0
# 36       3123.0       394.0         39.0         399.0  3157.0
# 42       2028.0       976.0         40.0         316.0  2728.0
# 41       2503.0       346.0         85.0         355.0  2579.0
# 45       1574.0       968.0        255.0         315.0  2482.0
# 6        1819.0       231.0         53.0         300.0  1803.0
# 25       1439.0       147.0         53.0         185.0  1454.0
# 34        746.0       938.0         65.0         428.0  1321.0
# 40        218.0       930.0         34.0         111.0  1071.0

# %%
#user_134088_tag_activity_agg.sort_values(by=["num_tag_search","score"],ascending=False).head(10)

# %% [markdown]
# #### Filter out tags that are not in the candidate set

# %%
tag_genome_trimmed = pd.read_csv("Datasets/Tag_Genome_with_Score_Trimmed.csv")
tag_candidates = tag_genome_trimmed['tag'].tolist()

# %%
# Rank tags by user_num_app, then by scores
user_134088_tag_activity_agg[user_134088_tag_activity_agg['tag'].isin(tag_candidates)].sort_values(by=["num_tag_search","score"],ascending=False).head(10)
# Out:
#                   tag  userId  num_tag_search     movieId  numApps  \
# 25           mindfuck  134088               9   5545415.0   1639.0
# 11             disney  134088               4   6244146.0    195.0
# 49               toys  134088               3   2088965.0     86.0
# 41  social commentary  134088               2  23265238.0   2934.0
# 23         loneliness  134088               2  12377546.0    949.0
# 17           gangster  134088               2  32321490.0    543.0
# 7           car chase  134088               2   9762464.0    541.0
# 46            surreal  134088               1  29702438.0   5047.0
# 1              action  134088               1  62353012.0   5917.0
# 36         psychology  134088               1  12818669.0   3556.0
#
#     numPositive  numNeutral  numNegative  numDownvotes   score
# 25       1439.0       147.0         53.0         185.0  1454.0
# 11         75.0       111.0          9.0          25.0   170.0
# 49         25.0        56.0          5.0          19.0    67.0
# 41       2503.0       346.0         85.0         355.0  2579.0
# 23        586.0       342.0         21.0         108.0   841.0
# 17         95.0       441.0          7.0          49.0   494.0
# 7         244.0       248.0         49.0         120.0   421.0
# 46       4256.0       669.0        122.0         554.0  4493.0
# 1        3687.0      1996.0        234.0        1515.0  4402.0
# 36       3123.0       394.0         39.0         399.0  3157.0
