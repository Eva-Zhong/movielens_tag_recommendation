# %% [markdown]
# ### Load unique tags

# %%
import pandas as pd

# %%
unique_tags = pd.read_csv("./unique_tags.csv")

# %%
unique_tags = unique_tags.drop("Unnamed: 0",axis=1)

# %% [markdown]
# ### Load word2vec model

# %%
import gensim
from gensim.models import Word2Vec

# %%
word_vec_model2 = Word2Vec.load('Word2Vec_fullds_model2')

# %%
len(word_vec_model2.wv.vocab)
# Out:
# 65012

# %%
word_vec_model2.wv.most_similar("happy")
# Out:
# [('happier', 0.27740973234176636),
#  ('happily', 0.2672647535800934),
#  ('happiest', 0.22986197471618652),
#  ('upbeat', 0.22156524658203125),
#  ('glad', 0.20897459983825684),
#  ('optimistic', 0.20554432272911072),
#  ('hopeful', 0.20425133407115936),
#  ('unhappy', 0.19973137974739075),
#  ('cheerful', 0.19736379384994507),
#  ('awww', 0.18560005724430084)]

# %%
word_vec_model2.wv.vocab
# Out:
# {'big': <gensim.models.keyedvectors.Vocab at 0x7f2874f65c18>,
#  'fan': <gensim.models.keyedvectors.Vocab at 0x7f2874f65cf8>,
#  'animate': <gensim.models.keyedvectors.Vocab at 0x7f2874f65d68>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7f2874f65dd8>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f2874f65e48>,
#  'pixar': <gensim.models.keyedvectors.Vocab at 0x7f2874f65eb8>,
#  'studios': <gensim.models.keyedvectors.Vocab at 0x7f2874f65f28>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7f2874f65f98>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f2874f71048>,
#  'newest': <gensim.models.keyedvectors.Vocab at 0x7f2874f710b8>,
#  'technological': <gensim.models.keyedvectors.Vocab at 0x7f2874f710f0>,
#  'possibilities': <gensim.models.keyedvectors.Vocab at 0x7f2874f71128>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f2874f71198>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x7f2874f71208>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f2874f71278>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f2874f712e8>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f2874f71358>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f2874f713c8>,
#  'decade': <gensim.models.keyedvectors.Vocab at 0x7f2874f71438>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f2874f714a8>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7f2874f71518>,
#  'toy': <gensim.models.keyedvectors.Vocab at 0x7f2874f71588>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f2874f715f8>,
#  'owner': <gensim.models.keyedvectors.Vocab at 0x7f2874f71668>,
#  'asleep': <gensim.models.keyedvectors.Vocab at 0x7f2874f716d8>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x7f2874f71748>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f2874f717b8>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7f2874f71828>,
#  'birthday': <gensim.models.keyedvectors.Vocab at 0x7f2874f71860>,
#  'nervous': <gensim.models.keyedvectors.Vocab at 0x7f2874f718d0>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f2874f71940>,
#  'ignore': <gensim.models.keyedvectors.Vocab at 0x7f2874f719b0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f2874f71a20>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f2874f71a90>,
#  'arrive': <gensim.models.keyedvectors.Vocab at 0x7f2874f71b00>,
#  'woody': <gensim.models.keyedvectors.Vocab at 0x7f2874f71b70>,
#  'cowboy': <gensim.models.keyedvectors.Vocab at 0x7f2874f71be0>,
#  'leader': <gensim.models.keyedvectors.Vocab at 0x7f2874f71c50>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x7f2874f71cc0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f2874f71d30>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x7f2874f71da0>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f2874f71dd8>,
#  'buzz': <gensim.models.keyedvectors.Vocab at 0x7f2874f71e48>,
#  'lightyear': <gensim.models.keyedvectors.Vocab at 0x7f2874f71e80>,
#  'hat': <gensim.models.keyedvectors.Vocab at 0x7f2874f71ef0>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f2874f71f60>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f2874f71f98>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7f2874f71fd0>,
#  'rid': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8080>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f2874ef80f0>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8160>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7f2874ef81d0>,
#  'appreciate': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8208>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8278>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f2874ef82e8>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8358>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f2874ef83c8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8400>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8470>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f2874ef84e0>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8518>,
#  'instance': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8550>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x7f2874ef85c0>,
#  'todays': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8630>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7f2874ef86a0>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8710>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8780>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7f2874ef87f0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8860>,
#  '1995': <gensim.models.keyedvectors.Vocab at 0x7f2874ef88d0>,
#  'computers': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8908>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8978>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f2874ef89e8>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8a20>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8a90>,
#  'unknown': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8b00>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8b70>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8be0>,
#  'creators': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8c18>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8c88>,
#  'animations': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8cc0>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8d30>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8d68>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8da0>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8e10>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8e80>,
#  'disney': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8ef0>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8f60>,
#  'animation': <gensim.models.keyedvectors.Vocab at 0x7f2874ef8f98>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f2874efc048>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x7f2874efc080>,
#  'actors': <gensim.models.keyedvectors.Vocab at 0x7f2874efc0f0>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x7f2874efc160>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7f2874efc1d0>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x7f2874efc240>,
#  'animals': <gensim.models.keyedvectors.Vocab at 0x7f2874efc2b0>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x7f2874efc320>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f2874efc390>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x7f2874efc400>,
#  'adventure': <gensim.models.keyedvectors.Vocab at 0x7f2874efc438>,
#  'friendship': <gensim.models.keyedvectors.Vocab at 0x7f2874efc470>,
#  'loyalty': <gensim.models.keyedvectors.Vocab at 0x7f2874efc4e0>,
#  'engross': <gensim.models.keyedvectors.Vocab at 0x7f2874efc550>,
#  'nail': <gensim.models.keyedvectors.Vocab at 0x7f2874efc5c0>,
#  'bite': <gensim.models.keyedvectors.Vocab at 0x7f2874efc630>,
#  'climax': <gensim.models.keyedvectors.Vocab at 0x7f2874efc6a0>,
#  'tom': <gensim.models.keyedvectors.Vocab at 0x7f2874efc710>,
#  'hanks': <gensim.models.keyedvectors.Vocab at 0x7f2874efc780>,
#  'tim': <gensim.models.keyedvectors.Vocab at 0x7f2874efc7f0>,
#  'allen': <gensim.models.keyedvectors.Vocab at 0x7f2874efc860>,
#  'performances': <gensim.models.keyedvectors.Vocab at 0x7f2874efc898>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7f2874efc908>,
#  'biggest': <gensim.models.keyedvectors.Vocab at 0x7f2874efc978>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f2874efc9e8>,
#  'spectacular': <gensim.models.keyedvectors.Vocab at 0x7f2874efca20>,
#  'besides': <gensim.models.keyedvectors.Vocab at 0x7f2874efca90>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f2874efcb00>,
#  'noteworthy': <gensim.models.keyedvectors.Vocab at 0x7f2874efcb38>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f2874efcba8>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f2874efcc18>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7f2874efcc88>,
#  'perspective': <gensim.models.keyedvectors.Vocab at 0x7f2874efccc0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f2874efcd30>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7f2874efcda0>,
#  'appropriate': <gensim.models.keyedvectors.Vocab at 0x7f2874efcdd8>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f2874efce10>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7f2874efce80>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f2874efcef0>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x7f2874efcf60>,
#  'revolutionary': <gensim.models.keyedvectors.Vocab at 0x7f2874efcf98>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x7f2874efcfd0>,
#  'startlingly': <gensim.models.keyedvectors.Vocab at 0x7f2874f02048>,
#  'realistic': <gensim.models.keyedvectors.Vocab at 0x7f2874f02080>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f2874f020f0>,
#  'tons': <gensim.models.keyedvectors.Vocab at 0x7f2874f02160>,
#  'thankfully': <gensim.models.keyedvectors.Vocab at 0x7f2874f02198>,
#  'filmmakers': <gensim.models.keyedvectors.Vocab at 0x7f2874f021d0>,
#  'explore': <gensim.models.keyedvectors.Vocab at 0x7f2874f02240>,
#  'dozens': <gensim.models.keyedvectors.Vocab at 0x7f2874f022b0>,
#  'hide': <gensim.models.keyedvectors.Vocab at 0x7f2874f02320>,
#  'woodwork': <gensim.models.keyedvectors.Vocab at 0x7f2874f02358>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x7f2874f02390>,
#  'songs': <gensim.models.keyedvectors.Vocab at 0x7f2874f02400>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x7f2874f02470>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7f2874f024e0>,
#  'subtle': <gensim.models.keyedvectors.Vocab at 0x7f2874f02550>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7f2874f025c0>,
#  'indiana': <gensim.models.keyedvectors.Vocab at 0x7f2874f02630>,
#  'jones': <gensim.models.keyedvectors.Vocab at 0x7f2874f026a0>,
#  'theme': <gensim.models.keyedvectors.Vocab at 0x7f2874f02710>,
#  'song': <gensim.models.keyedvectors.Vocab at 0x7f2874f02780>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7f2874f027f0>,
#  'knock': <gensim.models.keyedvectors.Vocab at 0x7f2874f02860>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x7f2874f028d0>,
#  'desk': <gensim.models.keyedvectors.Vocab at 0x7f2874f02940>,
#  'lamp': <gensim.models.keyedvectors.Vocab at 0x7f2874f029b0>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f2874f02a20>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f2874f02a90>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7f2874f02b00>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f2874f02b70>,
#  'adventurous': <gensim.models.keyedvectors.Vocab at 0x7f2874f02ba8>,
#  'excite': <gensim.models.keyedvectors.Vocab at 0x7f2874f02c18>,
#  'entertain': <gensim.models.keyedvectors.Vocab at 0x7f2874f02c50>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f2874f02cc0>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f2874f02d30>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f2874f02da0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f2874f02e10>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7f2874f02e80>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x7f2874f02ef0>,
#  'andy': <gensim.models.keyedvectors.Vocab at 0x7f2874f02f60>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f2874f02fd0>,
#  'reasonable': <gensim.models.keyedvectors.Vocab at 0x7f2874f08048>,
#  'peace': <gensim.models.keyedvectors.Vocab at 0x7f2874f080b8>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x7f2874f08128>,
#  'birthdays': <gensim.models.keyedvectors.Vocab at 0x7f2874f08160>,
#  'christmases': <gensim.models.keyedvectors.Vocab at 0x7f2874f08198>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7f2874f08208>,
#  'replace': <gensim.models.keyedvectors.Vocab at 0x7f2874f08278>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x7f2874f082e8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f2874f08358>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7f2874f083c8>,
#  'competition': <gensim.models.keyedvectors.Vocab at 0x7f2874f08400>,
#  'doll': <gensim.models.keyedvectors.Vocab at 0x7f2874f08470>,
#  'rivalries': <gensim.models.keyedvectors.Vocab at 0x7f2874f084a8>,
#  'boil': <gensim.models.keyedvectors.Vocab at 0x7f2874f08518>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7f2874f08588>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x7f2874f085f8>,
#  'accidentally': <gensim.models.keyedvectors.Vocab at 0x7f2874f08630>,
#  'push': <gensim.models.keyedvectors.Vocab at 0x7f2874f086a0>,
#  'expel': <gensim.models.keyedvectors.Vocab at 0x7f2874f08710>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x7f2874f08780>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x7f2874f087f0>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x7f2874f08860>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7f2874f088d0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f2874f08940>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f2874f089b0>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f2874f08a20>,
#  'essence': <gensim.models.keyedvectors.Vocab at 0x7f2874f08a90>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7f2874f08b00>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7f2874f08b70>,
#  'wit': <gensim.models.keyedvectors.Vocab at 0x7f2874f08be0>,
#  'joke': <gensim.models.keyedvectors.Vocab at 0x7f2874f08c50>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x7f2874f08cc0>,
#  'humour': <gensim.models.keyedvectors.Vocab at 0x7f2874f08d30>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7f2874f08da0>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7f2874f08e10>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f2874f08e80>,
#  'monsters': <gensim.models.keyedvectors.Vocab at 0x7f2874f08eb8>,
#  'inc': <gensim.models.keyedvectors.Vocab at 0x7f2874f08f28>,
#  'bug': <gensim.models.keyedvectors.Vocab at 0x7f2874f08f98>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d048>,
#  'refresh': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d0b8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d128>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d198>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d208>,
#  'comparison': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d240>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d2b0>,
#  'twist': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d320>,
#  'formula': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d390>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d400>,
#  'sharper': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d470>,
#  'reference': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d4a8>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d518>,
#  'background': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d550>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d5c0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d630>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d6a0>,
#  'deserve': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d710>,
#  'praise': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d780>,
#  'successful': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d7b8>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d828>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d860>,
#  'genuine': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d8d0>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d940>,
#  'excitement': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d978>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7f2874f0d9e8>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x7f2874f0da58>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x7f2874f0da90>,
#  'shore': <gensim.models.keyedvectors.Vocab at 0x7f2874f0db00>,
#  'conflict': <gensim.models.keyedvectors.Vocab at 0x7f2874f0db38>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f2874f0dba8>,
#  'deeper': <gensim.models.keyedvectors.Vocab at 0x7f2874f0dc18>,
#  'confront': <gensim.models.keyedvectors.Vocab at 0x7f2874f0dc50>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x7f2874f0dcc0>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x7f2874f0dd30>,
#  'turmoil': <gensim.models.keyedvectors.Vocab at 0x7f2874f0dda0>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f2874f0de10>,
#  'oppose': <gensim.models.keyedvectors.Vocab at 0x7f2874f0de80>,
#  'cartoon': <gensim.models.keyedvectors.Vocab at 0x7f2874f0def0>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f2874f0df60>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7f2874f0dfd0>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7f2874f14080>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x7f2874f140f0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f2874f14160>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f2874f141d0>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f2874f14240>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x7f2874f14278>,
#  'adult': <gensim.models.keyedvectors.Vocab at 0x7f2874f142e8>,
#  'potato': <gensim.models.keyedvectors.Vocab at 0x7f2874f14358>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f2874f143c8>,
#  'dinosaur': <gensim.models.keyedvectors.Vocab at 0x7f2874f14400>,
#  'pig': <gensim.models.keyedvectors.Vocab at 0x7f2874f14470>,
#  'slinky': <gensim.models.keyedvectors.Vocab at 0x7f2874f144e0>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x7f2874f14550>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7f2874f145c0>,
#  'majority': <gensim.models.keyedvectors.Vocab at 0x7f2874f145f8>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f2874f14668>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f2874f146d8>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f2874f14748>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7f2874f147b8>,
#  'cynical': <gensim.models.keyedvectors.Vocab at 0x7f2874f14828>,
#  'edge': <gensim.models.keyedvectors.Vocab at 0x7f2874f14898>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f2874f14908>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f2874f14978>,
#  'sales': <gensim.models.keyedvectors.Vocab at 0x7f2874f149e8>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7f2874f14a58>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f2874f14ac8>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x7f2874f14b38>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x7f2874f14b70>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7f2874f14be0>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x7f2874f14c50>,
#  'rub': <gensim.models.keyedvectors.Vocab at 0x7f2874f14cc0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7f2874f14d30>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x7f2874f14da0>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7f2874f14e10>,
#  'wonderfully': <gensim.models.keyedvectors.Vocab at 0x7f2874f14e48>,
#  'quickly': <gensim.models.keyedvectors.Vocab at 0x7f2874f14eb8>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f2874f14f28>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x7f2874f14f98>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7f2874f14fd0>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f2874f18080>,
#  'varney': <gensim.models.keyedvectors.Vocab at 0x7f2874f180f0>,
#  'ratzenberger': <gensim.models.keyedvectors.Vocab at 0x7f2874f18128>,
#  'ermey': <gensim.models.keyedvectors.Vocab at 0x7f2874f18198>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x7f2874f18208>,
#  'rickles': <gensim.models.keyedvectors.Vocab at 0x7f2874f18278>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x7f2874f182e8>,
#  'roles': <gensim.models.keyedvectors.Vocab at 0x7f2874f18358>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f2874f18390>,
#  'favourite': <gensim.models.keyedvectors.Vocab at 0x7f2874f183c8>,
#  'adults': <gensim.models.keyedvectors.Vocab at 0x7f2874f18438>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7f2874f184a8>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x7f2874f18518>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x7f2874f18588>,
#  'sharp': <gensim.models.keyedvectors.Vocab at 0x7f2874f185f8>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x7f2874f18668>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7f2874f186d8>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f2874f18748>,
#  'fly': <gensim.models.keyedvectors.Vocab at 0x7f2874f187b8>,
#  'downside': <gensim.models.keyedvectors.Vocab at 0x7f2874f187f0>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x7f2874f18860>,
#  'damn': <gensim.models.keyedvectors.Vocab at 0x7f2874f188d0>,
#  'clever': <gensim.models.keyedvectors.Vocab at 0x7f2874f18940>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x7f2874f189b0>,
#  'justifiably': <gensim.models.keyedvectors.Vocab at 0x7f2874f189e8>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x7f2874f18a20>,
#  'sequel': <gensim.models.keyedvectors.Vocab at 0x7f2874f18a90>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7f2874f18b00>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f2874f18b70>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x7f2874f18be0>,
#  'strut': <gensim.models.keyedvectors.Vocab at 0x7f2874f18c50>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x7f2874f18cc0>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f2874f18d30>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x7f2874f18da0>,
#  'routine': <gensim.models.keyedvectors.Vocab at 0x7f2874f18e10>,
#  'giant': <gensim.models.keyedvectors.Vocab at 0x7f2874f18e80>,
#  'leap': <gensim.models.keyedvectors.Vocab at 0x7f2874f18ef0>,
#  'stride': <gensim.models.keyedvectors.Vocab at 0x7f2874f18f60>,
#  'humor': <gensim.models.keyedvectors.Vocab at 0x7f2874f18fd0>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e080>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e0f0>,
#  'wallace': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e160>,
#  'shawn': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e1d0>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e240>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e2b0>,
#  'armstrong': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e2e8>,
#  'steal': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e358>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e3c8>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e438>,
#  'rex': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e4a8>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e4e0>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e550>,
#  'diminish': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e588>,
#  'entertainment': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e5c0>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e630>,
#  'catch': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e6a0>,
#  'audibly': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e710>,
#  'visually': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e748>,
#  'discover': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e780>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e7b8>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e828>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e860>,
#  'guarantee': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e898>,
#  'winner': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e908>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e978>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x7f2874f1e9b0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ea20>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ea90>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7f2874f1eb00>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7f2874f1eb70>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ebe0>,
#  'dolls': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ec50>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ecc0>,
#  'soldier': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ed30>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f2874f1eda0>,
#  'serve': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ee10>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ee80>,
#  'theory': <gensim.models.keyedvectors.Vocab at 0x7f2874f1eef0>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f2874f1ef60>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7f2874f1efd0>,
#  'chronicle': <gensim.models.keyedvectors.Vocab at 0x7f2874f23048>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7f2874f230b8>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f2874f23128>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x7f2874f23198>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f2874f23208>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f2874f23278>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x7f2874f232b0>,
#  'cherish': <gensim.models.keyedvectors.Vocab at 0x7f2874f23320>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7f2874f23390>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x7f2874f233c8>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x7f2874f23438>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f2874f234a8>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f2874f23518>,
#  'ernest': <gensim.models.keyedvectors.Vocab at 0x7f2874f23588>,
#  'ham': <gensim.models.keyedvectors.Vocab at 0x7f2874f235f8>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7f2874f23668>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7f2874f236d8>,
#  'cheer': <gensim.models.keyedvectors.Vocab at 0x7f2874f23748>,
#  'upstairs': <gensim.models.keyedvectors.Vocab at 0x7f2874f23780>,
#  'prime': <gensim.models.keyedvectors.Vocab at 0x7f2874f237f0>,
#  'suspect': <gensim.models.keyedvectors.Vocab at 0x7f2874f23860>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f2874f238d0>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f2874f23940>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x7f2874f239b0>,
#  'killer': <gensim.models.keyedvectors.Vocab at 0x7f2874f23a20>,
#  'sid': <gensim.models.keyedvectors.Vocab at 0x7f2874f23a90>,
#  'prove': <gensim.models.keyedvectors.Vocab at 0x7f2874f23b00>,
#  'innocence': <gensim.models.keyedvectors.Vocab at 0x7f2874f23b38>,
#  'safely': <gensim.models.keyedvectors.Vocab at 0x7f2874f23ba8>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7f2874f23c18>,
#  'element': <gensim.models.keyedvectors.Vocab at 0x7f2874f23c88>,
#  'shrug': <gensim.models.keyedvectors.Vocab at 0x7f2874f23cf8>,
#  'carelessly': <gensim.models.keyedvectors.Vocab at 0x7f2874f23d30>,
#  'thoughtlessly': <gensim.models.keyedvectors.Vocab at 0x7f2874f23d68>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7f2874f23dd8>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f2874f23e48>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f2874f23eb8>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x7f2874f23f28>,
#  'endless': <gensim.models.keyedvectors.Vocab at 0x7f2874f23f98>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x7f2874f28048>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f2874f280b8>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x7f2874f28128>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f2874f28198>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x7f2874f28208>,
#  'manage': <gensim.models.keyedvectors.Vocab at 0x7f2874f28278>,
#  'preach': <gensim.models.keyedvectors.Vocab at 0x7f2874f282e8>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x7f2874f28358>,
#  'equally': <gensim.models.keyedvectors.Vocab at 0x7f2874f283c8>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f2874f28400>,
#  'earlier': <gensim.models.keyedvectors.Vocab at 0x7f2874f28470>,
#  'wooden': <gensim.models.keyedvectors.Vocab at 0x7f2874f284e0>,
#  'plastic': <gensim.models.keyedvectors.Vocab at 0x7f2874f28550>,
#  'emotions': <gensim.models.keyedvectors.Vocab at 0x7f2874f28588>,
#  'qualities': <gensim.models.keyedvectors.Vocab at 0x7f2874f285c0>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x7f2874f285f8>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f2874f28668>,
#  'wicked': <gensim.models.keyedvectors.Vocab at 0x7f2874f286d8>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f2874f28748>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x7f2874f287b8>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7f2874f28828>,
#  'expressions': <gensim.models.keyedvectors.Vocab at 0x7f2874f28860>,
#  'movements': <gensim.models.keyedvectors.Vocab at 0x7f2874f28898>,
#  'screen': <gensim.models.keyedvectors.Vocab at 0x7f2874f28908>,
#  'generate': <gensim.models.keyedvectors.Vocab at 0x7f2874f28940>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x7f2874f289b0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f2874f28a20>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7f2874f28a90>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7f2874f28b00>,
#  'gesture': <gensim.models.keyedvectors.Vocab at 0x7f2874f28b70>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x7f2874f28be0>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x7f2874f28c18>,
#  'pot': <gensim.models.keyedvectors.Vocab at 0x7f2874f28c88>,
#  'belly': <gensim.models.keyedvectors.Vocab at 0x7f2874f28cf8>,
#  'believable': <gensim.models.keyedvectors.Vocab at 0x7f2874f28d30>,
#  'distinguish': <gensim.models.keyedvectors.Vocab at 0x7f2874f28d68>,
#  'traits': <gensim.models.keyedvectors.Vocab at 0x7f2874f28dd8>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f2874f28e48>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x7f2874f28eb8>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f2874f28f28>,
#  'forgettable': <gensim.models.keyedvectors.Vocab at 0x7f2874f28f60>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x7f2874f28f98>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e048>,
#  'era': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e0b8>,
#  'cheap': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e128>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e198>,
#  'sequels': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e208>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e278>,
#  'television': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e2b0>,
#  'babysitters': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e2e8>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e320>,
#  'jungle': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e390>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e400>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e438>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e4a8>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e518>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e588>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e5f8>,
#  'audience': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e630>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e668>,
#  'provocative': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e6a0>,
#  'ideas': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e710>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e780>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e7f0>,
#  'exact': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e860>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e8d0>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e940>,
#  'makers': <gensim.models.keyedvectors.Vocab at 0x7f2874f2e9b0>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ea20>,
#  'cash': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ea90>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x7f2874f2eb00>,
#  'posters': <gensim.models.keyedvectors.Vocab at 0x7f2874f2eb70>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ebe0>,
#  'proof': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ec50>,
#  'audiences': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ec88>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ecf8>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ed68>,
#  'nemo': <gensim.models.keyedvectors.Vocab at 0x7f2874f2edd8>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ee10>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ee80>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x7f2874f2eef0>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x7f2874f2ef60>,
#  '250': <gensim.models.keyedvectors.Vocab at 0x7f2874f2efd0>,
#  'imdb': <gensim.models.keyedvectors.Vocab at 0x7f2874f33080>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x7f2874f330f0>,
#  'unpromising': <gensim.models.keyedvectors.Vocab at 0x7f2874f33128>,
#  'trailer': <gensim.models.keyedvectors.Vocab at 0x7f2874f33198>,
#  'upcoming': <gensim.models.keyedvectors.Vocab at 0x7f2874f331d0>,
#  'license': <gensim.models.keyedvectors.Vocab at 0x7f2874f33240>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f2874f332b0>,
#  'dispute': <gensim.models.keyedvectors.Vocab at 0x7f2874f33320>,
#  'cough': <gensim.models.keyedvectors.Vocab at 0x7f2874f33390>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7f2874f33400>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7f2874f33438>,
#  '2005': <gensim.models.keyedvectors.Vocab at 0x7f2874f334a8>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x7f2874f334e0>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7f2874f33518>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7f2874f33588>,
#  'folks': <gensim.models.keyedvectors.Vocab at 0x7f2874f335f8>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x7f2874f33668>,
#  'brilliant': <gensim.models.keyedvectors.Vocab at 0x7f2874f336a0>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x7f2874f336d8>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x7f2874f33748>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x7f2874f337b8>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x7f2874f337f0>,
#  'remarkable': <gensim.models.keyedvectors.Vocab at 0x7f2874f33828>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x7f2874f33898>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f2874f33908>,
#  'traditional': <gensim.models.keyedvectors.Vocab at 0x7f2874f33940>,
#  'draw': <gensim.models.keyedvectors.Vocab at 0x7f2874f339b0>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x7f2874f33a20>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x7f2874f33a90>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7f2874f33b00>,
#  'combine': <gensim.models.keyedvectors.Vocab at 0x7f2874f33b70>,
#  'excellence': <gensim.models.keyedvectors.Vocab at 0x7f2874f33ba8>,
#  'genuinely': <gensim.models.keyedvectors.Vocab at 0x7f2874f33be0>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x7f2874f33c50>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x7f2874f33cc0>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x7f2874f33d30>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f2874f33da0>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f2874f33e10>,
#  'perfectionists': <gensim.models.keyedvectors.Vocab at 0x7f2874f33e48>,
#  'rarely': <gensim.models.keyedvectors.Vocab at 0x7f2874f33eb8>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f2874f33f28>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x7f2874f33f98>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x7f2874f33fd0>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f2874eba080>,
#  'library': <gensim.models.keyedvectors.Vocab at 0x7f2874eba0f0>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7f2874eba160>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f2874eba1d0>,
#  'string': <gensim.models.keyedvectors.Vocab at 0x7f2874eba240>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x7f2874eba2b0>,
#  'absorb': <gensim.models.keyedvectors.Vocab at 0x7f2874eba320>,
#  'younger': <gensim.models.keyedvectors.Vocab at 0x7f2874eba390>,
#  'demographic': <gensim.models.keyedvectors.Vocab at 0x7f2874eba3c8>,
#  'older': <gensim.models.keyedvectors.Vocab at 0x7f2874eba438>,
#  'ones': <gensim.models.keyedvectors.Vocab at 0x7f2874eba4a8>,
#  'mildly': <gensim.models.keyedvectors.Vocab at 0x7f2874eba518>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x7f2874eba550>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7f2874eba588>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f2874eba5f8>,
#  'maturity': <gensim.models.keyedvectors.Vocab at 0x7f2874eba630>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7f2874eba6a0>,
#  'magical': <gensim.models.keyedvectors.Vocab at 0x7f2874eba710>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7f2874eba780>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f2874eba7f0>,
#  'unexpected': <gensim.models.keyedvectors.Vocab at 0x7f2874eba828>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f2874eba898>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x7f2874eba908>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x7f2874eba978>,
#  'attract': <gensim.models.keyedvectors.Vocab at 0x7f2874eba9e8>,
#  'overload': <gensim.models.keyedvectors.Vocab at 0x7f2874ebaa20>,
#  'superstar': <gensim.models.keyedvectors.Vocab at 0x7f2874ebaa58>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7f2874ebaa90>,
#  'aforementioned': <gensim.models.keyedvectors.Vocab at 0x7f2874ebaac8>,
#  'unlike': <gensim.models.keyedvectors.Vocab at 0x7f2874ebab38>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x7f2874ebaba8>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7f2874ebac18>,
#  'faithful': <gensim.models.keyedvectors.Vocab at 0x7f2874ebac50>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x7f2874ebacc0>,
#  'sheer': <gensim.models.keyedvectors.Vocab at 0x7f2874ebad30>,
#  'delight': <gensim.models.keyedvectors.Vocab at 0x7f2874ebada0>,
#  'exceptional': <gensim.models.keyedvectors.Vocab at 0x7f2874ebadd8>,
#  'entirely': <gensim.models.keyedvectors.Vocab at 0x7f2874ebae10>,
#  'produce': <gensim.models.keyedvectors.Vocab at 0x7f2874ebae80>,
#  'extraordinary': <gensim.models.keyedvectors.Vocab at 0x7f2874ebaeb8>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7f2874ebaf28>,
#  'teach': <gensim.models.keyedvectors.Vocab at 0x7f2874ebaf98>,
#  'lessons': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0048>,
#  'mainly': <gensim.models.keyedvectors.Vocab at 0x7f2874ec00b8>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0128>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0198>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0208>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0278>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x7f2874ec02e8>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0358>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7f2874ec03c8>,
#  'escape': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0438>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f2874ec04a8>,
#  'cleverly': <gensim.models.keyedvectors.Vocab at 0x7f2874ec04e0>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0550>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7f2874ec05c0>,
#  'deposit': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0630>,
#  'nostalgia': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0668>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x7f2874ec06d8>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0748>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f2874ec07b8>,
#  '1990s': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0828>,
#  'bedroom': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0898>,
#  'populate': <gensim.models.keyedvectors.Vocab at 0x7f2874ec08d0>,
#  'playthings': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0908>,
#  '1960s': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0978>,
#  '1970s': <gensim.models.keyedvectors.Vocab at 0x7f2874ec09e8>,
#  '1980s': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0a58>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0ac8>,
#  'nintendo': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0b00>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0b70>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0be0>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0c50>,
#  'enjoyability': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0c88>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0cf8>,
#  'likeability': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0d30>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0da0>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0e10>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0e80>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0ef0>,
#  'kelly': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0f60>,
#  'heroes': <gensim.models.keyedvectors.Vocab at 0x7f2874ec0fd0>,
#  'oscar': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5080>,
#  'prickly': <gensim.models.keyedvectors.Vocab at 0x7f2874ec50f0>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5128>,
#  'lee': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5198>,
#  'standouts': <gensim.models.keyedvectors.Vocab at 0x7f2874ec51d0>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5208>,
#  'newfangled': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5240>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f2874ec52b0>,
#  'accept': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5320>,
#  'plaything': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5358>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f2874ec53c8>,
#  'medical': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5438>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f2874ec54a8>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5518>,
#  'panache': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5588>,
#  'william': <gensim.models.keyedvectors.Vocab at 0x7f2874ec55f8>,
#  'shatner': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5668>,
#  'parody': <gensim.models.keyedvectors.Vocab at 0x7f2874ec56d8>,
#  'underrate': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5710>,
#  'galaxy': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5780>,
#  'quest': <gensim.models.keyedvectors.Vocab at 0x7f2874ec57f0>,
#  'milestone': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5828>,
#  'neither': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5898>,
#  'represent': <gensim.models.keyedvectors.Vocab at 0x7f2874ec58d0>,
#  'innovative': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5908>,
#  'cleverest': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5940>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5978>,
#  'worthy': <gensim.models.keyedvectors.Vocab at 0x7f2874ec59e8>,
#  'apex': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5a58>,
#  'funnier': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5ac8>,
#  'merit': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5b38>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5ba8>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5c18>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5c88>,
#  'gobs': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5cf8>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5d68>,
#  'invest': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5dd8>,
#  'debut': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5e48>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5eb8>,
#  'tribute': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5f28>,
#  'randy': <gensim.models.keyedvectors.Vocab at 0x7f2874ec5f98>,
#  'newman': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb048>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb0b8>,
#  'textures': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb0f0>,
#  'surprisingly': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb128>,
#  'lifelike': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb160>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb198>,
#  'scud': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb208>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb278>,
#  'drool': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb2e8>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb358>,
#  'rote': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb3c8>,
#  'repeat': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb438>,
#  'transition': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb470>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb4e0>,
#  'mutilate': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb518>,
#  'genius': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb588>,
#  'vend': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb5f8>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb668>,
#  'alien': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb6d8>,
#  'gape': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb748>,
#  'rapt': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb7b8>,
#  'judgment': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb7f0>,
#  'claw': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb860>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb8d0>,
#  'pathos': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb940>,
#  'undeniable': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb978>,
#  'inner': <gensim.models.keyedvectors.Vocab at 0x7f2874ecb9e8>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x7f2874ecba58>,
#  'overs': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbac8>,
#  'fair': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbb38>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbba8>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbc18>,
#  'map': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbc88>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbcf8>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbd68>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbdd8>,
#  'throw': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbe48>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbeb8>,
#  'lad': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbf28>,
#  'conscience': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbf60>,
#  'alas': <gensim.models.keyedvectors.Vocab at 0x7f2874ecbfd0>,
#  'unknowingly': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0048>,
#  'mantle': <gensim.models.keyedvectors.Vocab at 0x7f2874ed00b8>,
#  'envy': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0128>,
#  'jealousy': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0160>,
#  'ignorance': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0198>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0208>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0278>,
#  'exceed': <gensim.models.keyedvectors.Vocab at 0x7f2874ed02e8>,
#  'rent': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0358>,
#  'noisy': <gensim.models.keyedvectors.Vocab at 0x7f2874ed03c8>,
#  'desperation': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0400>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0470>,
#  'christmas': <gensim.models.keyedvectors.Vocab at 0x7f2874ed04a8>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0518>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0550>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7f2874ed05c0>,
#  'nominally': <gensim.models.keyedvectors.Vocab at 0x7f2874ed05f8>,
#  'brokeback': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0630>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7f2874ed06a0>,
#  'bo': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0710>,
#  'peep': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0780>,
#  'smatter': <gensim.models.keyedvectors.Vocab at 0x7f2874ed07f0>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0828>,
#  'checker': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0898>,
#  'hang': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0908>,
#  'corrosion': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0940>,
#  'awareness': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0978>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7f2874ed09e8>,
#  'gather': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0a58>,
#  'expectantly': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0a90>,
#  'transistor': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0ac8>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0b38>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0ba8>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0c18>,
#  'troop': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0c88>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0cf8>,
#  'downstairs': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0d30>,
#  'gift': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0da0>,
#  'hop': <gensim.models.keyedvectors.Vocab at 0x7f2874ed0e10>,
# ...
#  'feature': <gensim.models.keyedvectors.Vocab at 0x7f2874ed75f8>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7668>,
#  'wave': <gensim.models.keyedvectors.Vocab at 0x7f2874ed76d8>,
#  'incidental': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7710>,
#  'slightly': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7748>,
#  'dodgy': <gensim.models.keyedvectors.Vocab at 0x7f2874ed77b8>,
#  'irrelevant': <gensim.models.keyedvectors.Vocab at 0x7f2874ed77f0>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7860>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f2874ed78d0>,
#  'finesse': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7940>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x7f2874ed79b0>,
#  'synonymous': <gensim.models.keyedvectors.Vocab at 0x7f2874ed79e8>,
#  'maudlin': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7a58>,
#  'redneck': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7ac8>,
#  'fundamentalism': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7b00>,
#  'anachronistic': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7b38>,
#  'boneheaded': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7b70>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7be0>,
#  'smart': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7c50>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7cc0>,
#  'youngsters': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7cf8>,
#  'hip': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7d68>,
#  'teens': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7dd8>,
#  'insufferable': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7e10>,
#  'pet': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7e80>,
#  'tyrannical': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7eb8>,
#  'umbrella': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7ef0>,
#  'overarch': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7f28>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7f60>,
#  'studio': <gensim.models.keyedvectors.Vocab at 0x7f2874ed7fd0>,
#  'somehow': <gensim.models.keyedvectors.Vocab at 0x7f2874edd080>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7f2874edd0f0>,
#  'trace': <gensim.models.keyedvectors.Vocab at 0x7f2874edd160>,
#  'craven': <gensim.models.keyedvectors.Vocab at 0x7f2874edd1d0>,
#  'doubly': <gensim.models.keyedvectors.Vocab at 0x7f2874edd240>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x7f2874edd278>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x7f2874edd2b0>,
#  'experimentation': <gensim.models.keyedvectors.Vocab at 0x7f2874edd2e8>,
#  'outa': <gensim.models.keyedvectors.Vocab at 0x7f2874edd358>,
#  'gate': <gensim.models.keyedvectors.Vocab at 0x7f2874edd3c8>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f2874edd438>,
#  'heartfelt': <gensim.models.keyedvectors.Vocab at 0x7f2874edd470>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x7f2874edd4a8>,
#  'depression': <gensim.models.keyedvectors.Vocab at 0x7f2874edd4e0>,
#  'emotional': <gensim.models.keyedvectors.Vocab at 0x7f2874edd518>,
#  'segment': <gensim.models.keyedvectors.Vocab at 0x7f2874edd588>,
#  'truly': <gensim.models.keyedvectors.Vocab at 0x7f2874edd5f8>,
#  'heartbreaking': <gensim.models.keyedvectors.Vocab at 0x7f2874edd630>,
#  'cheesy': <gensim.models.keyedvectors.Vocab at 0x7f2874edd6a0>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x7f2874edd710>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x7f2874edd780>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7f2874edd7f0>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x7f2874edd860>,
#  'lyric': <gensim.models.keyedvectors.Vocab at 0x7f2874edd8d0>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x7f2874edd940>,
#  'sail': <gensim.models.keyedvectors.Vocab at 0x7f2874edd9b0>,
#  'launch': <gensim.models.keyedvectors.Vocab at 0x7f2874edda20>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x7f2874edda58>,
#  'hankies': <gensim.models.keyedvectors.Vocab at 0x7f2874eddac8>,
#  'portrayal': <gensim.models.keyedvectors.Vocab at 0x7f2874eddb00>,
#  'triumphal': <gensim.models.keyedvectors.Vocab at 0x7f2874eddb38>,
#  'achievement': <gensim.models.keyedvectors.Vocab at 0x7f2874eddb70>,
#  'boldly': <gensim.models.keyedvectors.Vocab at 0x7f2874eddbe0>,
#  'contravene': <gensim.models.keyedvectors.Vocab at 0x7f2874eddc18>,
#  '1950': <gensim.models.keyedvectors.Vocab at 0x7f2874eddc88>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x7f2874eddcf8>,
#  'norman': <gensim.models.keyedvectors.Vocab at 0x7f2874eddd68>,
#  'rockwell': <gensim.models.keyedvectors.Vocab at 0x7f2874eddda0>,
#  'fantasy': <gensim.models.keyedvectors.Vocab at 0x7f2874edde10>,
#  'incarnations': <gensim.models.keyedvectors.Vocab at 0x7f2874edde48>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f2874eddeb8>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x7f2874eddf28>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f2874eddf98>,
#  'geniuses': <gensim.models.keyedvectors.Vocab at 0x7f2874eddfd0>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3080>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7f2874ee30f0>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3160>,
#  'pizza': <gensim.models.keyedvectors.Vocab at 0x7f2874ee31d0>,
#  'planet': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3240>,
#  'disappoint': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3278>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7f2874ee32e8>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3358>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x7f2874ee33c8>,
#  'universe': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3400>,
#  'adhere': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3470>,
#  'protocol': <gensim.models.keyedvectors.Vocab at 0x7f2874ee34a8>,
#  'inert': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3518>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3588>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f2874ee35f8>,
#  'instinct': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3630>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7f2874ee36a0>,
#  'vicious': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3710>,
#  'propose': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3780>,
#  'ingenuousness': <gensim.models.keyedvectors.Vocab at 0x7f2874ee37b8>,
#  'regard': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3828>,
#  'infuriate': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3860>,
#  'assassination': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3898>,
#  'concatenation': <gensim.models.keyedvectors.Vocab at 0x7f2874ee38d0>,
#  'accidents': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3908>,
#  'teamwork': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3940>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x7f2874ee39b0>,
#  'ingenuity': <gensim.models.keyedvectors.Vocab at 0x7f2874ee39e8>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3a58>,
#  'path': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3ac8>,
#  'ensconce': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3b00>,
#  'scorchingly': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3b38>,
#  'vignettes': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3b70>,
#  'fasten': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3be0>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3c50>,
#  'seatbelt': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3c88>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3cf8>,
#  'hyperventilate': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3d30>,
#  'mrs': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3da0>,
#  'nesbitt': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3e10>,
#  'climactic': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3e48>,
#  'rocket': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3eb8>,
#  'ride': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3f28>,
#  'callback': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3f60>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x7f2874ee3fd0>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9080>,
#  'seal': <gensim.models.keyedvectors.Vocab at 0x7f2874ee90f0>,
#  'greatness': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9128>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9198>,
#  'plausible': <gensim.models.keyedvectors.Vocab at 0x7f2874ee91d0>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9208>,
#  'anywhere': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9240>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f2874ee92b0>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9320>,
#  'infallible': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9358>,
#  'file': <gensim.models.keyedvectors.Vocab at 0x7f2874ee93c8>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9438>,
#  'filmmaker': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9470>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x7f2874ee94e0>,
#  'contain': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9550>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f2874ee95c0>,
#  'foresee': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9630>,
#  'afterwards': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9668>,
#  'verify': <gensim.models.keyedvectors.Vocab at 0x7f2874ee96d8>,
#  'francois': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9710>,
#  'truffaut': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9748>,
#  'glossy': <gensim.models.keyedvectors.Vocab at 0x7f2874ee97b8>,
#  'sexy': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9828>,
#  'sheen': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9898>,
#  'mere': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9908>,
#  'task': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9978>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x7f2874ee99e8>,
#  'evil': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9a58>,
#  'emperor': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9ac8>,
#  'zurg': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9b38>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9ba8>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9c18>,
#  'existence': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9c50>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9cc0>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9d30>,
#  'otherwise': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9d68>,
#  'youthful': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9da0>,
#  'exuberant': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9dd8>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9e48>,
#  'discard': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9eb8>,
#  'realist': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9f28>,
#  'fake': <gensim.models.keyedvectors.Vocab at 0x7f2874ee9f98>,
#  'facade': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0048>,
#  'tacky': <gensim.models.keyedvectors.Vocab at 0x7f2874ef00b8>,
#  'ipod': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0128>,
#  'veneer': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0198>,
#  'crazy': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0208>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0278>,
#  'timer': <gensim.models.keyedvectors.Vocab at 0x7f2874ef02e8>,
#  'realise': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0358>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7f2874ef03c8>,
#  'elite': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0438>,
#  'protection': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0470>,
#  'unit': <gensim.models.keyedvectors.Vocab at 0x7f2874ef04e0>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0518>,
#  'reveal': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0588>,
#  'weakness': <gensim.models.keyedvectors.Vocab at 0x7f2874ef05c0>,
#  'fool': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0630>,
#  'naturally': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0668>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x7f2874ef06a0>,
#  'idiot': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0710>,
#  'brainwash': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0748>,
#  'desperate': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0780>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f2874ef07f0>,
#  'identity': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0828>,
#  'merely': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0898>,
#  'elevate': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0908>,
#  'believers': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0940>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0978>,
#  'exaggerate': <gensim.models.keyedvectors.Vocab at 0x7f2874ef09b0>,
#  'importance': <gensim.models.keyedvectors.Vocab at 0x7f2874ef09e8>,
#  'idle': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0a58>,
#  'worldly': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0ac8>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0b38>,
#  'adopt': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0ba8>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0c18>,
#  'dour': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0c88>,
#  'midway': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0cf8>,
#  'stumble': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0d68>,
#  'horde': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0dd8>,
#  'worship': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0e48>,
#  'mechanical': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0e80>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0ef0>,
#  'descend': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0f60>,
#  'pluck': <gensim.models.keyedvectors.Vocab at 0x7f2874ef0fd0>,
#  'heaven': <gensim.models.keyedvectors.Vocab at 0x7f2874e75080>,
#  'delude': <gensim.models.keyedvectors.Vocab at 0x7f2874e750f0>,
#  'souls': <gensim.models.keyedvectors.Vocab at 0x7f2874e75160>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x7f2874e751d0>,
#  'devilish': <gensim.models.keyedvectors.Vocab at 0x7f2874e75208>,
#  'cid': <gensim.models.keyedvectors.Vocab at 0x7f2874e75278>,
#  'phillips': <gensim.models.keyedvectors.Vocab at 0x7f2874e752b0>,
#  'sadistic': <gensim.models.keyedvectors.Vocab at 0x7f2874e752e8>,
#  'nirvana': <gensim.models.keyedvectors.Vocab at 0x7f2874e75358>,
#  'whisper': <gensim.models.keyedvectors.Vocab at 0x7f2874e753c8>,
#  'airlift': <gensim.models.keyedvectors.Vocab at 0x7f2874e75438>,
#  'deaths': <gensim.models.keyedvectors.Vocab at 0x7f2874e754a8>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f2874e75518>,
#  'scenario': <gensim.models.keyedvectors.Vocab at 0x7f2874e75550>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7f2874e755c0>,
#  'witness': <gensim.models.keyedvectors.Vocab at 0x7f2874e75630>,
#  'commercial': <gensim.models.keyedvectors.Vocab at 0x7f2874e75668>,
#  'advertise': <gensim.models.keyedvectors.Vocab at 0x7f2874e756a0>,
#  'vast': <gensim.models.keyedvectors.Vocab at 0x7f2874e75710>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7f2874e75780>,
#  'ordinary': <gensim.models.keyedvectors.Vocab at 0x7f2874e757b8>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x7f2874e75828>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x7f2874e75898>,
#  'nietzschean': <gensim.models.keyedvectors.Vocab at 0x7f2874e758d0>,
#  'metaphor': <gensim.models.keyedvectors.Vocab at 0x7f2874e75908>,
#  'transcend': <gensim.models.keyedvectors.Vocab at 0x7f2874e75940>,
#  'flesh': <gensim.models.keyedvectors.Vocab at 0x7f2874e759b0>,
#  'injection': <gensim.models.keyedvectors.Vocab at 0x7f2874e759e8>,
#  'mould': <gensim.models.keyedvectors.Vocab at 0x7f2874e75a58>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x7f2874e75a90>,
#  'seek': <gensim.models.keyedvectors.Vocab at 0x7f2874e75b00>,
#  'refuge': <gensim.models.keyedvectors.Vocab at 0x7f2874e75b70>,
#  'denial': <gensim.models.keyedvectors.Vocab at 0x7f2874e75be0>,
#  'climb': <gensim.models.keyedvectors.Vocab at 0x7f2874e75c50>,
#  'staircase': <gensim.models.keyedvectors.Vocab at 0x7f2874e75c88>,
#  'validate': <gensim.models.keyedvectors.Vocab at 0x7f2874e75cc0>,
#  'defy': <gensim.models.keyedvectors.Vocab at 0x7f2874e75d30>,
#  'laws': <gensim.models.keyedvectors.Vocab at 0x7f2874e75da0>,
#  'dom': <gensim.models.keyedvectors.Vocab at 0x7f2874e75e10>,
#  ...}

# %%
similar_terms = {}
items_no_neighbors = []

# %%
for index, row in unique_tags.iterrows():
    tag = row['tags']
    if tag in word_vec_model2.wv.vocab:
        similar_terms[tag] = word_vec_model2.wv.most_similar(tag)
    else:
        items_no_neighbors.append(tag)

# %%
items_no_neighbors
# Out:
# ['007 (series)',
#  '18th century',
#  '19th century',
#  '9/11',
#  'aardman studios',
#  'action packed',
#  'adapted from:book',
#  'adapted from:comic',
#  'adapted from:game',
#  'afi 100',
#  'afi 100 (laughs)',
#  'afi 100 (movie quotes)',
#  'aging',
#  'aids',
#  'alien invasion',
#  'aliens',
#  'alone in the world',
#  'alter ego',
#  'alternate endings',
#  'alternate history',
#  'alternate reality',
#  'alternate universe',
#  'amazing cinematography',
#  'amazing photography',
#  'american civil war',
#  'amy smart',
#  'android(s)/cyborg(s)',
#  'animal movie',
#  'animated',
#  'anti-hero',
#  'anti-semitism',
#  'anti-war',
#  'arms dealer',
#  'art house',
#  'artificial intelligence',
#  'author:alan moore',
#  'author:neil gaiman',
#  'awesome soundtrack',
#  'bad acting',
#  'bad cgi',
#  'bad ending',
#  'bad plot',
#  'bad science',
#  'bad script',
#  'bad sequel',
#  'bank robbery',
#  'based on a book',
#  'based on a comic',
#  'based on a play',
#  'based on a true story',
#  'based on a tv show',
#  'based on a video game',
#  'based on book',
#  'based on comic',
#  'based on true story',
#  'beautiful scenery',
#  'beautifully filmed',
#  'beauty pageant',
#  'best of 2005',
#  'best war films',
#  'better than expected',
#  'better than the american version',
#  'big budget',
#  'birds',
#  'biting',
#  'black and white',
#  'black comedy',
#  'boarding school',
#  'bombs',
#  'book was better',
#  'books',
#  'boring',
#  'boring!',
#  'bowling',
#  'boxing',
#  'brainwashing',
#  'british comedy',
#  'buddy movie',
#  'bullshit history',
#  'bullying',
#  'c.s. lewis',
#  'car chase',
#  'carrie-anne moss',
#  'character study',
#  'cheating',
#  'cheerleading',
#  'chick flick',
#  'child abuse',
#  'chris tucker',
#  'civil war',
#  'classic car',
#  'classical music',
#  'clones',
#  'cloning',
#  'clowns',
#  'coen bros',
#  'coen brothers',
#  'cold war',
#  'comic book',
#  'comic book adaption',
#  'coming of age',
#  'coming-of-age',
#  'complex characters',
#  'complicated',
#  'complicated plot',
#  'computer animation',
#  'computer game',
#  'con artists',
#  'con men',
#  'confusing',
#  'conspiracy theory',
#  'cooking',
#  'corporate america',
#  'costume drama',
#  'courtroom drama',
#  'crappy sequel',
#  'crime gone awry',
#  'cross dressing',
#  'crude humor',
#  'cult classic',
#  'cult film',
#  'culture clash',
#  'cute!',
#  'dancing',
#  'dark comedy',
#  'dark fantasy',
#  'dark hero',
#  'dark humor',
#  'dc comics',
#  'death penalty',
#  'depp & burton',
#  'depressing',
#  'dialogue driven',
#  'directorial debut',
#  'disappointing',
#  'disney animated feature',
#  'distopia',
#  'disturbing',
#  'doctors',
#  'dogs',
#  'dr. seuss',
#  'dreams',
#  'drinking',
#  'drug abuse',
#  'drug addiction',
#  'drugs',
#  'dumb but funny',
#  'dynamic cgi action',
#  'dysfunctional family',
#  'dystopic future',
#  'easily confused with other movie(s) (title)',
#  'east germany',
#  'effects',
#  'emma watson',
#  'end of the world',
#  'ennio morricone',
#  'enormously long battle scene',
#  'ensemble cast',
#  'entertaining',
#  'entirely dialogue',
#  'ethnic conflict',
#  'excellent script',
#  'exceptional acting',
#  'exciting',
#  'fairy tale',
#  'fairy tales',
#  'fake documentary',
#  'family bonds',
#  'family drama',
#  'fantasy world',
#  'fast paced',
#  'father daughter relationship',
#  'father son relationship',
#  'father-son relationship',
#  'feel good movie',
#  'feel-good',
#  'fight scenes',
#  'fighting',
#  'fighting the system',
#  'figure skating',
#  'film noir',
#  'first contact',
#  'foul language',
#  'fountain of youth',
#  'francis ford copolla',
#  'free speech',
#  'free to download',
#  'frightening',
#  'fun movie',
#  'funniest movies',
#  'funny as hell',
#  'gambling',
#  'gangs',
#  'gay character',
#  'george orwell',
#  'ghosts',
#  'ghosts/afterlife',
#  'giant robots',
#  'girlie movie',
#  'global warming',
#  'golden palm',
#  'good acting',
#  'good action',
#  'good dialogue',
#  'good music',
#  'good romantic comedies',
#  'good sequel',
#  'good soundtrack',
#  'good story',
#  'good versus evil',
#  'goretastic',
#  'graphic design',
#  'graphic novel',
#  'gratuitous violence',
#  'great acting',
#  'great cinematography',
#  'great dialogue',
#  'great ending',
#  'great movie',
#  'great music',
#  'great soundtrack',
#  'gross-out',
#  'guilty pleasure',
#  'gulf war',
#  'guns',
#  'gypsy accent',
#  'hacking',
#  'hannibal lecter',
#  'happy ending',
#  'hard to watch',
#  'harry potter',
#  'haunted house',
#  'heroine in tight suit',
#  'high fantasy',
#  'high school',
#  'highly quotable',
#  'hip hop',
#  'hit men',
#  'hong kong',
#  'horses',
#  'hunting',
#  'imaginary friend',
#  'imdb top 250',
#  'independent film',
#  'indiana jones',
#  'innocence lost',
#  'inspiring',
#  'intelligent sci-fi',
#  'interesting',
#  'interracial romance',
#  'iraq war',
#  'irish accent',
#  'james bond',
#  'jane austen',
#  'jay and silent bob',
#  'kick-butt women',
#  'kidnapping',
#  'kids',
#  'kids and family',
#  'king arthur',
#  'kung fu',
#  'las vegas',
#  'latin america',
#  'life & death',
#  'life philosophy',
#  'literary adaptation',
#  'liv tyler',
#  'lone hero',
#  'los angeles',
#  'love story',
#  'love triangles',
#  'low budget',
#  'mad scientist',
#  'made for tv',
#  'magic realism',
#  'male nudity',
#  'man versus machine',
#  'mars',
#  'martial arts',
#  'marx brothers',
#  'memory loss',
#  'mental hospital',
#  'mental illness',
#  'middle east',
#  'midlife crisis',
#  'mindfuck',
#  'mining',
#  'mission from god',
#  'mistaken identity',
#  'modern fantasy',
#  'monty python',
#  'moral ambiguity',
#  'mother daughter relationship',
#  'mother-son relationship',
#  'mountain climbing',
#  'movie business',
#  'movielens top pick',
#  'moving',
#  'multiple storylines',
#  'murder mystery',
#  'music business',
#  'narrated',
#  'native americans',
#  'natural disaster',
#  'neil gaiman',
#  'neo-nazis',
#  'neo-noir',
#  'new jersey',
#  'new orleans',
#  'new york',
#  'new york city',
#  'new zealand',
#  'no dialogue',
#  'no plot',
#  'noir thriller',
#  'non-hollywood ending',
#  'non-linear',
#  'not as good as the first',
#  'not funny',
#  'notable nudity',
#  'notable soundtrack',
#  'nuclear bomb',
#  'nuclear war',
#  'nudity (full frontal - brief)',
#  'nudity (full frontal - notable)',
#  'nudity (full frontal)',
#  'nudity (rear)',
#  'nudity (topless - brief)',
#  'nudity (topless - notable)',
#  'nudity (topless)',
#  'off-beat comedy',
#  'organized crime',
#  'original plot',
#  'orphans',
#  'oscar (best actor)',
#  'oscar (best actress)',
#  'oscar (best animated feature)',
#  'oscar (best cinematography)',
#  'oscar (best directing)',
#  'oscar (best editing)',
#  'oscar (best effects - visual effects)',
#  'oscar (best foreign language film)',
#  'oscar (best music - original score)',
#  'oscar (best music - original song)',
#  'oscar (best picture)',
#  'oscar (best sound)',
#  'oscar (best supporting actor)',
#  'oscar (best supporting actress)',
#  'oscar (best writing - screenplay written directly for the screen)',
#  'oscar winner',
#  'over the top',
#  'overrated',
#  'parallel universe',
#  'period piece',
#  'peter pan',
#  'pg-13',
#  'philip k. dick',
#  'pigs',
#  'pirates',
#  'pixar animation',
#  'plot holes',
#  'plot twist',
#  'police corruption',
#  'police investigation',
#  'political corruption',
#  'post apocalyptic',
#  'post-apocalyptic',
#  'potential oscar nom',
#  'powerful ending',
#  'prison escape',
#  'private detective',
#  'product placement',
#  'rabbits',
#  'race issues',
#  'racing',
#  'rags to riches',
#  'rats',
#  'realistic action',
#  'reality tv',
#  'remade',
#  'rio de janeiro',
#  'road movie',
#  'road trip',
#  'roald dahl',
#  'robert downey jr',
#  'robert ludlum',
#  'rock and roll',
#  'romantic comedy',
#  'sad but good',
#  'san francisco',
#  'saturday night live',
#  'saturn award (best science fiction film)',
#  'saturn award (best special effects)',
#  'sci fi',
#  'sci-fi',
#  'science fiction',
#  'scifi cult',
#  'screwball comedy',
#  'secret service',
#  'self discovery',
#  'serial killer',
#  'sex comedy',
#  'sexual abuse',
#  'sexualized violence',
#  'shopping',
#  'short-term memory loss',
#  'silly fun',
#  'single father',
#  'slow paced',
#  'small town',
#  'snakes',
#  "so bad it's funny",
#  "so bad it's good",
#  'social commentary',
#  'sophia coppola',
#  'south africa',
#  'south america',
#  'southern theme',
#  'space opera',
#  'space program',
#  'space travel',
#  'spaghetti western',
#  'spanish civil war',
#  'special effects',
#  'spelling bee',
#  'spies',
#  'sports',
#  'spying',
#  'stage magic',
#  'stand-up comedy',
#  'star trek',
#  'star wars',
#  'stereotypes',
#  'stoner movie',
#  'stop motion',
#  'stop-motion',
#  'stranded',
#  'studio ghibli',
#  'stunning',
#  'stupid as hell',
#  'stylized',
#  'suicide attempt',
#  'super hero',
#  'super-hero',
#  'suprisingly clever',
#  'surfing',
#  'surprise ending',
#  'switching places',
#  'sword fight',
#  'sword fighting',
#  'talking animals',
#  'tear jerker',
#  'teen movie',
#  'terminal illness',
#  'thought-provoking',
#  'time loop',
#  'time travel',
#  'tom clancy',
#  'too long',
#  'too short',
#  'touching',
#  'toys',
#  'trains',
#  'treasure hunt',
#  'true story',
#  'truman capote',
#  'twist ending',
#  'twists & turns',
#  'undercover cop',
#  'underrated',
#  'understated',
#  'unintentionally funny',
#  'united nations',
#  'unlikeable characters',
#  'unlikely friendships',
#  'unusual plot structure',
#  'us history',
#  'vampire human love',
#  'very funny',
#  'very good',
#  'very interesting',
#  'video game',
#  'video game adaptation',
#  'video games',
#  'vietnam war',
#  'view askew',
#  'virtual reality',
#  'visually appealing',
#  'visually stunning',
#  'war movie',
#  'waste of time',
#  'watch the credits',
#  'wedding',
#  'witches',
#  'working class',
#  'world politics',
#  'world war i',
#  'world war ii',
#  "writer's life",
#  'writing']

# %% [markdown]
# ### TODO: Identify similar tags for those not in word_vec_model

# %% [markdown]
# ### Load previous tag classes

# %%
tag_classes = pd.read_csv("./tag_classes.csv")

tag_classes = tag_classes.drop("Unnamed: 0",axis=1)

# %%
tag_classes.tail(10)
# Out:
#                                     tag    tagClass
# 3100                         young kids       facts
# 3101                        younger men       facts
# 3102  your out of ur element donnie!!!!       other
# 3103                              youth       facts
# 3104                        zack snyder       facts
# 3105                             zero 7       other
# 3106                             zombie       facts
# 3107                            zombies       facts
# 3108                                zoo       facts
# 3109                               [ok]  subjective

# %%
tag_classes.groupby("tagClass").count()
# Out:
#              tag
# tagClass
# facts       1862
# other        183
# personal      99
# subjective   966

# %% [markdown]
# #### Categorize tags in tag genome based on tag_classes dataset (from 2006)

# %%
#tag_classes[tag_classes.tag == "007"].iloc[1]

result = tag_classes.loc[tag_classes.tag == "007","tagClass"]
result.values[0]
# Out:
# 'facts'

# %%
tag_class_col = []

for index, row in unique_tags.iterrows():
    aTag = row['tags']
    if any(tag_classes.tag == aTag):
        print(aTag)
        tag_class_col.append(tag_classes.loc[tag_classes.tag == aTag,"tagClass"].values[0])
    else:
        tag_class_col.append("TBD")
# Out:
# 007
# 18th century
# 1920s
# 1930s
# 1950s
# 1960s
# 1970s
# 1980s
# 19th century
# 80s
# aardman
# abortion
# action
# adaptation
# addiction
# adolescence
# adoption
# adultery
# adventure
# africa
# aging
# aids
# airport
# alcatraz
# alcoholism
# alien
# aliens
# alternate endings
# alternate reality
# alternate universe
# amazing cinematography
# amazing photography
# american civil war
# amnesia
# androids
# animal movie
# animals
# animated
# animation
# anime
# antarctica
# anti-semitism
# archaeology
# arms dealer
# arnold
# art
# art house
# artistic
# artsy
# assassin
# assassination
# assassins
# astronauts
# australia
# australian
# autism
# aviation
# awesome
# awful
# bad acting
# ballet
# baseball
# based on a book
# based on a true story
# based on a tv show
# based on book
# based on comic
# basketball
# batman
# bdsm
# beatles
# beautiful
# beer
# best of 2005
# best war films
# better than expected
# biblical
# biographical
# biography
# biopic
# birds
# bittersweet
# black and white
# black comedy
# blaxploitation
# blindness
# blood
# bloody
# boarding school
# boat
# bond
# book
# book was better
# books
# boring
# boston
# bowling
# boxing
# brainwashing
# brazil
# brilliant
# british
# british comedy
# broadway
# brothers
# brutal
# buddy movie
# business
# c.s. lewis
# california
# camp
# campy
# canada
# cancer
# cannibalism
# caper
# capitalism
# car chase
# cars
# cartoon
# casino
# catholicism
# censorship
# cgi
# chase
# cheesy
# chess
# chicago
# chick flick
# child abuse
# childhood
# children
# china
# chocolate
# christian
# christmas
# cinematography
# circus
# civil war
# classic
# classical music
# claymation
# clever
# cloning
# coen bros
# coen brothers
# cold war
# college
# comedy
# comic
# comic book
# comics
# coming of age
# coming-of-age
# communism
# competition
# complex
# complicated
# complicated plot
# computer animation
# computers
# con men
# confusing
# conspiracy
# cool
# corporate america
# corruption
# court
# courtroom
# crime
# cross dressing
# cuba
# cult classic
# cult film
# cute
# cyberpunk
# cyborgs
# dance
# dark
# dark comedy
# dark fantasy
# death
# death penalty
# demons
# depressing
# depression
# detective
# devil
# dialogue
# dinosaurs
# directorial debut
# disability
# disappointing
# disaster
# disney
# distopia
# divorce
# doctors
# documentary
# dogs
# dr. seuss
# dragon
# dragons
# drama
# dramatic
# dreams
# drug abuse
# drugs
# dumb
# dumb but funny
# dystopia
# educational
# emotional
# end of the world
# england
# enigmatic
# ennio morricone
# ensemble cast
# entertaining
# environment
# epic
# erotic
# espionage
# ethnic conflict
# evolution
# excellent
# exceptional acting
# exciting
# fairy tale
# fairy tales
# fake documentary
# family
# family drama
# fantasy
# fantasy world
# fashion
# fast paced
# fbi
# feel-good
# fighting
# figure skating
# film noir
# firefly
# fish
# food
# football
# foreign
# france
# francis ford copolla
# free speech
# freedom
# french
# friendship
# frightening
# fun
# fun movie
# funniest movies
# funny
# funny as hell
# future
# gambling
# gangs
# gangster
# gangsters
# gay
# geeks
# genetics
# genius
# genocide
# german
# germany
# ghosts
# giant robots
# gilliam
# girlie movie
# glbt
# god
# golf
# good
# good acting
# good action
# good dialogue
# good music
# good soundtrack
# gore
# goretastic
# gory
# great
# great acting
# great ending
# great movie
# great soundtrack
# greed
# gulf war
# gunfight
# guns
# gypsy accent
# hackers
# halloween
# hannibal lecter
# harry potter
# harsh
# haunted house
# hawaii
# heartbreaking
# heartwarming
# heist
# heroin
# high fantasy
# high school
# hilarious
# hillarious
# hip hop
# historical
# history
# hit men
# hitchcock
# hitman
# holiday
# hollywood
# holocaust
# homeless
# homophobia
# homosexuality
# honest
# hong kong
# horrible
# horror
# horses
# humanity
# humor
# idiotic
# imaginary friend
# immigrants
# immortality
# incest
# independent film
# india
# indiana jones
# indians
# indie
# infidelity
# inspirational
# inspiring
# intelligent
# intense
# interesting
# internet
# interracial romance
# investigation
# iraq
# ireland
# irish
# islam
# island
# israel
# italian
# italy
# james bond
# jane austen
# japan
# japanese
# jay and silent bob
# jazz
# jesus
# jewish
# jews
# journalism
# judaism
# jungle
# justice
# kidnapping
# kids
# king arthur
# kubrick
# kung fu
# kurosawa
# lame
# las vegas
# lawyer
# lawyers
# lesbian
# life
# light
# lions
# liv tyler
# london
# long
# los angeles
# love
# love story
# lynch
# lyrical
# mafia
# magic
# magic realism
# marijuana
# marriage
# mars
# martial arts
# marvel
# marx brothers
# masterpiece
# math
# mathematics
# medieval
# melancholic
# memory
# memory loss
# mental hospital
# mental illness
# mexico
# middle east
# midlife crisis
# military
# mining
# miyazaki
# mob
# mockumentary
# money
# monkey
# monster
# monsters
# monty python
# moon
# morality
# mountain climbing
# movie business
# moving
# mozart
# mtv
# mummy
# muppets
# murder
# music
# music business
# musical
# mystery
# nasa
# native americans
# nature
# nazi
# nazis
# neo-nazis
# nerds
# new orleans
# new york
# new york city
# no plot
# noir
# nonlinear
# nostalgia
# nostalgic
# nuclear
# nuclear bomb
# nuclear war
# nudity
# obsession
# ocean
# office
# oil
# olympics
# opera
# organized crime
# original
# original plot
# orphans
# oscar
# oscar (best actress)
# oscar winner
# overrated
# palestine
# paranoia
# parenthood
# paris
# parody
# penguins
# perfect
# peter pan
# philip k. dick
# philosophy
# photographer
# photography
# pigs
# pirates
# pixar
# plot twist
# poignant
# pointless
# poker
# poland
# police
# political
# politics
# poverty
# powerful ending
# predictable
# pregnancy
# prejudice
# prequel
# president
# prison
# prison escape
# propaganda
# prostitution
# psychiatrist
# psychology
# pulp
# puppets
# quirky
# race
# race issues
# racism
# radio
# rape
# reality tv
# rebellion
# redemption
# relationships
# religion
# remade
# remake
# revenge
# revolution
# rio de janeiro
# road movie
# road trip
# roald dahl
# robbery
# robot
# robots
# rock and roll
# romance
# romantic
# romantic comedy
# rome
# runaway
# russia
# sad
# sad but good
# samurai
# san francisco
# satire
# saturday night live
# scary
# scenic
# schizophrenia
# school
# sci-fi
# science fiction
# scifi
# scifi cult
# scotland
# screwball
# screwball comedy
# secrets
# sentimental
# sequel
# serial killer
# sex
# sexual abuse
# sexuality
# sexy
# shakespeare
# shark
# short
# silent
# silly
# sisters
# skinhead
# slapstick
# slasher
# slavery
# slow
# small town
# soccer
# south africa
# south america
# southern theme
# space
# space opera
# space program
# space travel
# spaghetti western
# spain
# spanish
# special
# special effects
# spelling bee
# spiders
# spielberg
# spies
# splatter
# spoof
# sports
# spy
# spying
# stand-up comedy
# star trek
# stereotypes
# stop motion
# stop-motion
# story
# stranded
# stupid
# stupidity
# stylish
# submarine
# suburbia
# suicide
# suicide attempt
# super-hero
# superhero
# supernatural
# suprisingly clever
# surfing
# surprise ending
# surreal
# surrealism
# survival
# suspense
# swashbuckler
# swedish
# sweet
# switching places
# sword fighting
# tarantino
# teacher
# tear jerker
# technology
# teen
# teenagers
# teens
# television
# terminal illness
# terrorism
# texas
# thought-provoking
# thriller
# time travel
# tokyo
# tolkien
# tom clancy
# too long
# too short
# touching
# toys
# tragedy
# train
# trains
# transformation
# treasure
# tricky
# trilogy
# true story
# truman capote
# twist
# twist ending
# twists & turns
# underdog
# underrated
# underwater
# unique
# unrealistic
# us history
# vampire
# vampires
# very funny
# very good
# very interesting
# video game
# vienna
# vietnam
# vietnam war
# view askew
# violence
# violent
# virginity
# virtual reality
# visual
# voyeurism
# war
# war movie
# wartime
# waste of time
# weapons
# wedding
# weird
# werewolf
# werewolves
# western
# whimsical
# wilderness
# wine
# witch
# witty
# wizards
# women
# working class
# workplace
# world war i
# world war ii
# writing
# wuxia
# wwii
# zombie
# zombies

# %%
len(tag_class_col)
# Out:
# 1128

# %%
unique_tags['tag_class']=tag_class_col

# %%
unique_tags.to_csv("./unique_tags_classes.csv")
