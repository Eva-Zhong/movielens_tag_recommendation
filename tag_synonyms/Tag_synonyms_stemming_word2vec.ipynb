# %% [markdown]
# ### Load tag genome tags

# %%
import pandas as pd

# %%
unique_tags = pd.read_csv("./unique_tags.csv")

# %%
unique_tags = unique_tags.drop("Unnamed: 0",axis=1)

# %%
unique_tags_list = unique_tags.tags.tolist()

# %% [markdown]
# ### Load all tags

# %%
tag_score = pd.read_csv("./tag_with_scores.csv")

# %%
tag_score.drop(['Unnamed: 0','movieId'],axis=1,inplace=True)

# %%
tag_score.dropna(inplace=True)

# %%
tag_list = tag_score['tag'].tolist()

# %% [markdown]
# ### Use word2vec to identify synonyms

# %%
from __future__ import print_function
from os.path import dirname
import os,sys,inspect

current_dir = dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
manage_dir = dirname(dirname(dirname(current_dir)))

if not manage_dir in sys.path:
    sys.path.insert(0, manage_dir)

# from pyml4.common import context, db
# context.local_context.print_summary()

import gensim
from gensim.models import Word2Vec
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
import logging
import nltk
import nltk.data
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import SnowballStemmer
from nltk.corpus import webtext
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.corpus import stopwords
import pymysql.cursors

# %%
word_vec_model2 = Word2Vec.load('Word2Vec_fullds_model2')

# %%
len(word_vec_model2.wv.vocab)
# Out:
# 65012

# %%
word_vec_model2.wv.similar_by_word("happy")
# Out:
# [('happier', 0.27740973234176636),
#  ('happily', 0.2672647535800934),
#  ('happiest', 0.22986197471618652),
#  ('upbeat', 0.22156524658203125),
#  ('glad', 0.20897459983825684),
#  ('optimistic', 0.20554432272911072),
#  ('hopeful', 0.20425133407115936),
#  ('unhappy', 0.19973137974739075),
#  ('cheerful', 0.19736379384994507),
#  ('awww', 0.18560005724430084)]

# %%
synonym = {}

for tag in tag_list:
    if tag in word_vec_model2.wv.vocab:
        if tag not in synonym:
            synonym[tag] = []

        for (k,v) in word_vec_model2.wv.similar_by_word(tag):
            if k in tag_list:
                synonym[tag].append(k)

# %% [markdown]
# ### Use stemming to identify potential similar tags

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
ps = PorterStemmer()

# %%
stem_result = {}
dup_words = []

for w in tag_list:
    #print(w) 
    curstem = ps.stem(w)
    if curstem in stem_result:
        stem_result[curstem].append(w)
    else:
        stem_result[curstem] = []
        stem_result[curstem].append(w)

# %%
stem_result["zombi"]
# Out:
# ['zombies', 'zombie', 'Zombie', 'Zombies', 'zombis']

# %%
for key, value in stem_result.items():
    if len(value) > 1:
        for word in value:
            dup_words.append(word)

# %%
len(dup_words)
# Out:
# 17743

# %%
import csv


with open('./dup_tags_among_all.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    for val in dup_words:
        wr.writerow([val])

# %% [markdown]
# #### Add tag stems as a new column to tag_score

# %%
tag_stems = []

for w in tag_list:
    curstem = ps.stem(w)
    tag_stems.append(curstem)

# %%
tag_score["tag_stem"] = tag_stems

# %%
tag_score_sorted = tag_score.sort_values(by=["tag_stem","score"],ascending=False)

# %%
tag_score_sorted_small = tag_score_sorted[tag_score_sorted["score"]>=2]

# %%
## For each tag, find tags with the same stem. 
## Add 'tag_same_stem' as a new column to tag_score_sorted.

tag_same_stem = []

for index, row in tag_score_sorted.iterrows():
    tag = row[0]
    stem = row[7]
    temp = ''
    if stem in stem_result:
        #same_stem_list = stem_result[stem]
        
        for t in stem_result[stem]:
            if t != tag:
                #temp.append(k)
                temp += t+";"
    if temp != '':
        tag_same_stem.append(temp)
    else:
        tag_same_stem.append(None)

# %%
tag_score_sorted["tags_same_stem"] = tag_same_stem

# %%
tag_score_sorted.count()
# Out:
# tag                      72776
# numApps                  72776
# numPositive              72776
# numNeutral               72776
# numNegative              72776
# numDownvotes             72776
# score                    72776
# tag_stem                 72776
# word2vec_similar_tags     9853
# tags_same_stem           17743
# dtype: int64

# %% [markdown]
# #### Exclude tags with scores < 2 (bad tags)

# %%
tag_score_sorted_small = tag_score_sorted[tag_score_sorted["score"]>=2].copy()

# %%
tag_score_sorted_small.count()
# Out:
# tag                      25305
# numApps                  25305
# numPositive              25305
# numNeutral               25305
# numNegative              25305
# numDownvotes             25305
# score                    25305
# tag_stem                 25305
# word2vec_similar_tags     6212
# tags_same_stem           10169
# dtype: int64

# %%
tag_score_sorted_small.drop_duplicates("tag_stem",keep="first",inplace=True)

# %%
tag_score_sorted_small
# Out:
#                                  tag  numApps  numPositive  numNeutral  \
# 14598                       Érotique        4            0           4
# 19808                         Å¡Åuk        4            0           4
# 19750                  Ángel Salazar        2            1           1
# 11223             Álex de la Iglesia       10            2           8
# 9402                          zurich        7            0           7
# 18433                           zulu        3            1           2
# 22151                    Zosia Mamet        2            0           1
# 19787                          zorro        2            0           2
# 18434                      zoophilia        4            1           2
# 19965                      zoologist        2            0           2
# 11134                      zookeeper        5            0           5
# 558                  Zooey Deschanel      286          228          47
# 2595                             zoo       42            0          42
# 18459                  zombification        3            0           3
# 22145                   Zombie Movie       17            7           7
# 13396                    Zombie dogs        7            2           1
# 2161               zombie apocalypse       47           13          34
# 89                           zombies     1403          860         434
# 13405                   Zoltan Korda        8            1           6
# 22140                    Zoey Deutch        4            4           0
# 4679                     Zoe Saldana       28           21           7
# 22190                    Zoe Kravitz        4            3           0
# 19972                      zoe kazan        2            1           1
# 22226                       Zoe Bell       14           13           1
# 19902                         zodiac        3            0           3
# 8455                          zlist1       10            0          10
# 22240                   Zizek's pick        3            2           1
# 12473                          Zizek        9            9           0
# 10339                        zionism        6            0           6
# 22238                       Zimbabwe        4            0           4
# ...                              ...      ...          ...         ...
# 13151                   13th century        4            0           4
# 8686                    12th century       13            1          12
# 5156          12 years in the making       17           12           4
# 11617                   11th century        5            2           3
# 11658  11 year old explicit violence        8            2           2
# 18112                   10th century        3            0           3
# 18111               1001 night tales        3            1           1
# 7419             100 Greatest Movies       74           68           3
# 19620    10 minutes of spinning crap        3            0           1
# 18099                           1/18        3            0           3
# 18121                            077        3            0           3
# 18221                          03/15        7            0           7
# 19689                          02/15        5            0           5
# 5170                    007 (series)       84           63          12
# 673                              007      254           98         145
# 19488                      /suspense        2            0           2
# 19567       ************************        2            0           2
# 19559           'bad religion' trope        2            0           0
# 14450                      '60s feel        4            4           0
# 19947                      &suspense        2            0           2
# 18424                          #nice        3            1           2
# 18439                       #fantasy        3            0           3
# 14287                        #boring        4            0           4
# 19861                   "The Hunter"        4            4           0
# 19771           "retrofitted" future        2            0           2
# 18425                  "potty" jokes        4            1           0
# 19733               "not so perfect"        8            0           8
# 1585                 "found footage"       88           51          24
# 19752         "based on true events"        2            0           2
# 19759                        "artsy"        2            1           0
#
#        numNegative  numDownvotes   score                     tag_stem  \
# 14598            0             0     4.0                      érotiqu
# 19808            0             2     2.0                       å¡åuk
# 19750            0             0     2.0                ángel salazar
# 11223            0             5     5.0           álex de la iglesia
# 9402             0             0     7.0                       zurich
# 18433            0             0     3.0                         zulu
# 22151            1             0     2.0                  zosia mamet
# 19787            0             0     2.0                        zorro
# 18434            1             1     3.0                    zoophilia
# 19965            0             0     2.0                    zoologist
# 11134            0             0     5.0                      zookeep
# 558             11            64   222.0              zooey deschanel
# 2595             0             4    38.0                          zoo
# 18459            0             0     3.0                       zombif
# 22145            3            15     2.0                  zombie movi
# 13396            4             3     4.0                   zombie dog
# 2161             0             0    47.0             zombie apocalyps
# 89             109           282  1121.0                        zombi
# 13405            1             4     4.0                 zoltan korda
# 22140            0             2     2.0                  zoey deutch
# 4679             0            10    18.0                  zoe saldana
# 22190            1             2     2.0                  zoe kravitz
# 19972            0             0     2.0                    zoe kazan
# 22226            0            12     2.0                      zoe bel
# 19902            0             1     2.0                       zodiac
# 8455             0             2     8.0                       zlist1
# 22240            0             1     2.0                 zizek's pick
# 12473            0             4     5.0                        zizek
# 10339            0             0     6.0                      zionism
# 22238            0             2     2.0                      zimbabw
# ...            ...           ...     ...                          ...
# 13151            0             0     4.0                 13th centuri
# 8686             0             5     8.0                 12th centuri
# 5156             1             1    16.0          12 years in the mak
# 11617            0             0     5.0                 11th centuri
# 11658            4             3     5.0    11 year old explicit viol
# 18112            0             0     3.0                 10th centuri
# 18111            1             0     3.0               1001 night tal
# 7419             3            64    10.0            100 greatest movi
# 19620            2             1     2.0  10 minutes of spinning crap
# 18099            0             0     3.0                         1/18
# 18121            0             0     3.0                          077
# 18221            0             4     3.0                        03/15
# 19689            0             3     2.0                        02/15
# 5170             9            68    16.0                 007 (series)
# 673             11            72   182.0                          007
# 19488            0             0     2.0                     /suspens
# 19567            0             0     2.0     ************************
# 19559            2             0     2.0          'bad religion' trop
# 14450            0             0     4.0                    '60s feel
# 19947            0             0     2.0                     &suspens
# 18424            0             0     3.0                        #nice
# 18439            0             0     3.0                     #fantasi
# 14287            0             0     4.0                        #bore
# 19861            0             2     2.0                 "the hunter"
# 19771            0             0     2.0          "retrofitted" futur
# 18425            3             1     3.0                  "potty" jok
# 19733            0             6     2.0             "not so perfect"
# 1585            13            19    69.0              "found footage"
# 19752            0             0     2.0       "based on true events"
# 19759            1             0     2.0                      "artsy"
#
#                                    word2vec_similar_tags  \
# 14598                                               None
# 19808                                               None
# 19750                                               None
# 11223                                               None
# 9402    switzerland;istanbul;heidelberg;amsterdam;paris;
# 18433                  algiers;bataan;waterloo;carthage;
# 22151                                               None
# 19787   swashbuckling;telenovela;swashbuckler;swordsman;
# 18434                                               None
# 19965  archaeologist;paleontologist;biologist;scienti...
# 11134                                    zoo;childbirth;
# 558                                                 None
# 2595                     animals;leopard;farm;zoologist;
# 18459           haiti;contamination;mutations;contagion;
# 22145                                               None
# 13396                                               None
# 2161                                                None
# 89     zombie;undead;ghouls;monsters;spiders;corpses;...
# 13405                                               None
# 22140                                               None
# 4679                                                None
# 22190                                               None
# 19972                                               None
# 22226                                               None
# 19902                                  serial;collector;
# 8455                                                None
# 22240                                               None
# 12473                                               None
# 10339                   jew;kabbalah;mccarthyism;shtetl;
# 22238                                               None
# ...                                                  ...
# 13151                                               None
# 8686                                                None
# 5156                                                None
# 11617                                               None
# 11658                                               None
# 18112                                               None
# 18111                                               None
# 7419                                                None
# 19620                                               None
# 18099                                               None
# 18121                                               None
# 18221                                               None
# 19689                                               None
# 5170                                                None
# 673                                        bond;mi6;spy;
# 19488                                               None
# 19567                                               None
# 19559                                               None
# 14450                                               None
# 19947                                               None
# 18424                                               None
# 18439                                               None
# 14287                                               None
# 19861                                               None
# 19771                                               None
# 18425                                               None
# 19733                                               None
# 1585                                                None
# 19752                                               None
# 19759                                               None
#
#                       tags_same_stem
# 14598                           None
# 19808                           None
# 19750                           None
# 11223                           None
# 9402                         Zurich;
# 18433                           None
# 22151                           None
# 19787                         Zorro;
# 18434                           None
# 19965                           None
# 11134                           None
# 558                 zooey deschanel;
# 2595                            Zoo;
# 18459                           None
# 22145                           None
# 13396                           None
# 2161              Zombie Apocalypse;
# 89     zombie;Zombie;Zombies;zombis;
# 13405                           None
# 22140                           None
# 4679                            None
# 22190                   zoe kravitz;
# 19972                     Zoe Kazan;
# 22226                           None
# 19902                           None
# 8455                            None
# 22240                  zizek's pick;
# 12473                         zizek;
# 10339                           None
# 22238                      zimbabwe;
# ...                              ...
# 13151                  13th Century;
# 8686                   12th Century;
# 5156                            None
# 11617                           None
# 11658                           None
# 18112                           None
# 18111                           None
# 7419            100 greatest movies;
# 19620                           None
# 18099                           None
# 18121                           None
# 18221                           None
# 19689                           None
# 5170                            None
# 673                             None
# 19488                           None
# 19567                           None
# 19559                           None
# 14450                           None
# 19947                           None
# 18424                           None
# 18439                           None
# 14287                           None
# 19861                           None
# 19771                           None
# 18425                           None
# 19733                           None
# 1585                            None
# 19752                           None
# 19759                           None
#
# [21171 rows x 10 columns]

# %% [markdown]
# ### Use word2vec to identify similar tags

# %%
from __future__ import print_function
from os.path import dirname
import os,sys,inspect

current_dir = dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
manage_dir = dirname(dirname(dirname(current_dir)))

if not manage_dir in sys.path:
    sys.path.insert(0, manage_dir)

# from pyml4.common import context, db
# context.local_context.print_summary()

import gensim
from gensim.models import Word2Vec
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
import logging
import nltk
import nltk.data
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import SnowballStemmer
from nltk.corpus import webtext
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.corpus import stopwords
import pymysql.cursors

# %%
word_vec_model2 = Word2Vec.load('Word2Vec_fullds_model2')

# %%
len(word_vec_model2.wv.vocab)
# Out:
# 65012

# %%
word_vec_model2.wv.similar_by_word("happy")
# Out:
# [('happier', 0.27740973234176636),
#  ('happily', 0.2672647535800934),
#  ('happiest', 0.22986197471618652),
#  ('upbeat', 0.22156524658203125),
#  ('glad', 0.20897459983825684),
#  ('optimistic', 0.20554432272911072),
#  ('hopeful', 0.20425133407115936),
#  ('unhappy', 0.19973137974739075),
#  ('cheerful', 0.19736379384994507),
#  ('awww', 0.18560005724430084)]

# %%
synonym = {}

for tag in tag_list:
    if tag in word_vec_model2.wv.vocab:
        if tag not in synonym:
            synonym[tag] = []

        for (k,v) in word_vec_model2.wv.similar_by_word(tag):
            if k in tag_list:
                synonym[tag].append(k)

# %%
similar_tags = []

for index, row in tag_score.iterrows():
    tag = row[0]
    temp = ''
    if tag in word_vec_model2.wv.vocab:
        for (k,v) in word_vec_model2.wv.similar_by_word(tag):
            if k in tag_list:
                #temp.append(k)
                temp += k+";"
    if len(temp) > 0:
        similar_tags.append(temp)
    else:
        similar_tags.append(None)

# %%
len(similar_tags)
# Out:
# 72776

# %%
tag_score['word2vec_similar_tags'] = similar_tags

# %%
tag_score.head()
# Out:
#             tag  numApps  numPositive  numNeutral  numNegative  numDownvotes  \
# 0        sci-fi     9094         6887        2083          124          1286
# 1   atmospheric     6127         5612         487           28           763
# 2       surreal     5115         4313         677          125           554
# 3        action     6006         3740        2030          236          1519
# 4  twist ending     4666         4081         477          108           589
#
#     score   tag_stem                              word2vec_similar_tags
# 0  7808.0     sci-fi                                               None
# 1  5364.0  atmospher  eerie;atmosphere;evocative;moody;stylish;suspe...
# 2  4561.0    surreal  surrealistic;nightmarish;dreamlike;bizarre;sur...
# 3  4487.0     action  suspense;suspenseful;pace;slapstick;drama;tens...
# 4  4077.0  twist end                                               None

# %% [markdown]
# ### Tags 1 edit away

# %% [markdown]
# #### Find tags 1 edit away for each tag; append to tag_score table

# %%
one_edit = []

for i in range (1,len(tag_list)):
    temp = ''
    tag1 = tag_list[i]
    for j in range (i+1,len(tag_list)):
        tag2 = tag_list[j]

        if isEditDistanceOne(tag1, tag2):
            temp += tag2 + ";"
    one_edit.append(temp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-3520fa2c9e0a> in <module>()
#       7         tag2 = tag_list[j]
#       8
# ----> 9         if isEditDistanceOne(tag1, tag2):
#      10             temp += tag2 + ";"
#      11     one_edit.append(temp)
#
# <ipython-input-52-38686d2b7c58> in isEditDistanceOne(s1, s2)
#       7     # If difference between lengths is more than 1,
#       8     # then strings can't be at one distance
# ----> 9     if abs(m - n) > 1:
#      10         return False
#      11
#
# KeyboardInterrupt:

# %%
one_edit

# %%
len(one_edit)

# %% [markdown]
# ======================old stuff================

# %%
duplicates = []

for i in range (1,len(tag_list)):
    count = 0
    tag1 = tag_list[i]
    for j in range (i+1,len(tag_list)):
        tag2 = tag_list[j]

        if isEditDistanceOne(tag1, tag2):
            count = count + 1
            duplicates.append(tag1)
            duplicates.append(tag2)

# %%
duplicates

# %%
import csv

with open('./tag_1_edit_away.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    for val in duplicates:
        wr.writerow([val])

# %% [markdown]
# ### A function that identifies if two words are <=1 edit away

# %%
def isEditDistanceOne(s1, s2):
 
    # Find lengths of given strings
    m = len(s1)
    n = len(s2)
 
    # If difference between lengths is more than 1,
    # then strings can't be at one distance
    if abs(m - n) > 1:
        return False
 
    count = 0    # Count of isEditDistanceOne
 
    i = 0
    j = 0
    while i < m and j < n:
        # If current characters dont match
        if s1[i] != s2[j]:
            if count == 1:
                return False
 
            # If length of one string is
            # more, then only possible edit
            # is to remove a character
            if m > n:
                i+=1
            elif m < n:
                j+=1
            else:    # If lengths of both strings is same
                i+=1
                j+=1
 
            # Increment count of edits
            count+=1
 
        else:    # if current characters match
            i+=1
            j+=1
 
    # if last character is extra in any string
    if i < m or j < n:
        count+=1
 
    return count <= 1
